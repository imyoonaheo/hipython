# %%
# mysql 서버에 연결
con = pymysql.connect(
  host= 'localhost',
  user= 'root',
  password= '1234',
  db= 'wntrade',
  charset= 'utf8'
) #한글처리(charset = 'utf8')
#커서 생성 
cursor = con.cursor()

# %%
cursor.execute("show tables")
# Out:
# 7

# %%
for row in cursor.fetchall():
  print(row)
# Out:
# ('고객',)
# ('마일리지등급',)
# ('부서',)
# ('사원',)
# ('제품',)
# ('주문',)
# ('주문세부',)

# %%
sql = """
select 사원번호, 이름, 부서명 
from 사원 left join 부서 
on 사원.사원번호 = 부서.부서번호;
"""

# %%
cursor.execute(sql)
# Out:
# 10

# %%
for row in cursor.fetchall():
  print(row)
# Out:
# ('E01', '이소미', None)
# ('E02', '배재용', None)
# ('E03', '유대현', None)
# ('E04', '최소민', None)
# ('E05', '안주훈', None)
# ('E06', '이현진', None)
# ('E07', '오영수', None)
# ('E08', '선하라', None)
# ('E09', '유가을', None)
# ('E10', '정수진', None)

# %%
cursor.close()
con.close()
