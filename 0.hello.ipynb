# %% [markdown]
# print("Hello, Jupyter!")

# %%
#헬로우

# %%
3*4
# Out:
# 12

# %%
#"안녕하세요" "반갑습니다"

# %%
5*4
2*3

# %%
"반갑습니다"
# Out:
# '반갑습니다'

# %%
print("Merry Christmas Eve")
# Out:
# Merry Christmas Eve

# %%
"""안녕하세요
반갑습니다"""
# Out:
# '안녕하세요\n반갑습니다'

# %%
def calculate_sum (a,b):
    result = a + b
    return result

if result > 0
    print
# Out:
#   Cell In[12], line 5
#     if result > 0
#                  ^
# SyntaxError: expected ':'

# %% [markdown]
# def calculate_sum(a, b):
#     result = a + b    # 들여쓰기된 코드 블록
#     return result     # 같은 레벨의 들여쓰기
#
# result = calculate_sum
#
# if result > 0:
#     print("양수입니다")    # if문 내부의 들여쓰기된 코드

# %%
def calculate_sum(a, b):
    result = a + b    # 들여쓰기된 코드 블록
    return result     # 같은 레벨의 들여쓰기

result = calculate_sum (3,4)

if result > 0:
    print("양수입니다")    # if문 내부의 들여쓰기된 코드
# Out:
# 양수입니다

# %%
print(result)
# Out:
# 7

# %%
def calculate_sum(a, b):
    result = a + b    # 들여쓰기된 코드 블록
    return result     # 같은 레벨의 들여쓰기

result = calculate_sum (3,4)

if result > 0:
    print(result)
    print("양수입니다")    # if문 내부의 들여쓰기된 코드
# Out:
# 7
# 양수입니다

# %% [markdown]
# 안녕하세요

# %% [markdown]
# #안녕하세요

# %%
#안녕하세요

# %% [markdown]
# #안녕하세요

# %% [markdown]
# # 안녕하세요

# %% [markdown]
# # Jypyter Notebook

# %% [markdown]
# ## hello

# %% [markdown]
# ### 3 level

# %% [markdown]
# #### 4 level

# %% [markdown]
# * 하나
# * 둘
# * 셋

# %% [markdown]
# 1. 하나
# 2. 둘
# 3. 셋

# %% [markdown]
# * 첫번째
#     - 서브리스트 1

# %% [markdown]
# * 첫번째
#     - 서브리스트 1
#         - 아이템

# %% [markdown]
# * 첫번째
#       - 서브리스트

# %% [markdown]
# * 안녕
#   - 서브리스트

# %% [markdown]
# **개구리 점프**
# | 번호 | 내용 | 주의사항 |
# | ------ | ------|
# | 1 | 선택한다 | 아무거나 |

# %% [markdown]
# **개구리 점프**
# | 번호 | 내용 | 주의사항
# | ---- | ----| ---- |

# %% [markdown]
# **개구리 점프**
# | 번호 | 이름 | 주의사항 |
# | ---- | ---- | ---- |
# | 1 | 개구리 |
# | 2 | 도마뱀 |

# %% [markdown]
# ## ![image.png](attachment:1512a661-4b76-4de9-b60e-482543043005.png)![image.png](attachment:9959983b-8c34-48b7-8217-9f57e2a1d65a.png)

# %% [markdown]
# ## ![image.png](attachment:c516f6ae-9767-4c7d-aafe-e628f3b08ee1.png)

# %% [markdown]
# > https://youtu.be/JSFG-IE8n_c?si=2VPder_BD-Fe2bkg
