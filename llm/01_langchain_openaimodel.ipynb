# %%
import os

if 'OPENAI_API_KEY' in os.environ:
    del os.environ['OPENAI_API_KEY']

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-4o-mini")

# invoke() - 단일 입력, 단일 응답 (동기)
response = llm.invoke("삼성전자 주가에 영향을 주는 요인은?")
print(response.content)
# Out:
# 삼성전자 주가에 영향을 주는 요인은 여러 가지가 있습니다. 주요 요인을 아래와 같이 정리할 수 있습니다.
#
# 1. **실적 발표**: 삼성전자의 분기 및 연간 실적 발표는 주가에 직접적인 영향을 미칩니다. 매출 및 영업이익, 순이익 등이 예상치에 부합하거나 초과할 경우 긍정적인 영향을 미치고, 반대로 예상보다 낮을 경우 부정적인 영향을 줍니다.
#
# 2. **시장 동향**: 글로벌 IT 및 전자제품 시장의 동향, 경쟁사들의 성과, 시장 점유율 변화 등이 삼성전자의 주가에 영향을 미칩니다.
#
# 3. **환율 변동**: 삼성전자는 해외에서 많은 수익을 올리는 글로벌 기업이므로 원화와 달러 간의 환율 변화가 주가에 중요한 영향을 미칩니다.
#
# 4. **경제 전반의 흐름**: 국내외 경제 성장률, 금리 변화, 인플레이션 등의 거시 경제적 요인이 삼성전자의 사업 환경에 영향을 미칩니다.
#
# 5. **기술 혁신 및 신제품 출시**: 새로운 기술 개발과 제품 출시, 특히 반도체, 모바일 기기, TV와 같은 주요 제품군의 혁신은 투자자 신뢰도와 직결되어 주가에 영향을 미칠 수 있습니다.
#
# 6. **정치적 요인**: 국내외 정치적 안정성, 무역 정책, 특히 미중 무역 갈등이나 북한과의 관계 등도 주가에 영향을 줄 수 있습니다.
#
# 7. **투자자의 심리**: 시장 전반의 투자 심리나 개인 및 기관 투자자의 매수/매도 행동 역시 주가에 영향을 미칩니다.
#
# 8. **배당금 정책**: 배당금 지급 결정이나 배당금의 변화도 주가에 영향을 미치는 요소입니다.
#
# 이 외에도 다양한 내외부 요인이 복합적으로 작용하여 삼성전자 주가에 영향을 미치므로, 투자 결정을 내릴 때는 이러한 요소들을 종합적으로 고려해야 합니다.

# %%
# batch() - 여러 입력을 한 번에 처리 (동기)
# 중복 토큰을 줄여 묶어 처리 → 비용 절감 효과
questions = [
    "삼성전자 주가에 영향을 주는 요인은?",
    "코스피 지수란 무엇인가?",
    "ETF와 펀드의 차이는?"
]
responses = llm.batch(questions)
for r in responses:
    print(r.content)
    print()
# Out:
# 삼성전자 주가에 영향을 미치는 요인은 여러 가지가 있습니다. 주요 요인은 다음과 같습니다:
#
# 1. **재무 실적**: 삼성전자의 분기별 및 연간 실적 발표는 주가에 큰 영향을 미칩니다. 매출, 순이익, 주당순이익(EPS) 등의 지표가 긍정적일 경우 주가가 상승할 가능성이 높습니다.
#
# 2. **산업 동향**: 반도체, 스마트폰, 가전제품 등 삼성전자가 속한 산업의 트렌드와 성장 전망도 중요합니다. 예를 들어, 반도체 수요가 증가하면 주가에 긍정적인 영향을 줄 수 있습니다.
#
# 3. **경쟁 상황**: 애플, 화웨이, 샤오미 등 경쟁사의 움직임이나 신제품 출시도 삼성전자 주가에 많은 영향을 미칩니다.
#
# 4. **글로벌 경제 여건**: 세계 경제의 성장률, 환율, 금리 변화 등도 주가에 영향을 미칩니다. 특히, 반도체 제품은 해외 수출 비중이 높기 때문에 글로벌 경제와 밀접한 연관이 있습니다.
#
# 5. **정치적 요인**: 한국이나 주요 거래국의 정치적 안정성, 무역 정책 등의 변화가 삼성전자 주가에 영향을 미칠 수 있습니다.
#
# 6. **기술 혁신**: 새로운 기술 개발이나 제품 혁신이 이루어질 경우 삼성전자의 시장 경쟁력에 긍정적인 영향을 미치고, 이는 곧 주가 상승으로 이어질 수 있습니다.
#
# 7. **투자자 심리**: 주식 시장의 전반적인 분위기나 소비자 및 투자자의 심리도 주가에 중요한 영향을 미칩니다.
#
# 이 외에도 다양한 외부 요인들이 복합적으로 작용하여 삼성전자 주가에 영향을 미칠 수 있습니다.
#
# 코스피(KOSPI) 지수는 대한민국의 주식 시장에서 거래되는 상장 기업들의 주식 가치를 종합적으로 나타내는 주식 시장 지수입니다. 'KOSPI'는 'Korea Composite Stock Price Index'의 약자로, 한국거래소(KRX)에서 운영하며, 1980년 1월 4일에 시작되었습니다.
#
# 코스피 지수는 한국 주식 시장의 전반적인 성과를 평가하는 데 사용되며, 주식 시장에 투자하는 투자자들에게 중요한 기준이 됩니다. 이 지수는 시장에서 가장 큰 기업들의 주식 가격을 기반으로 가중 평균 방식으로 계산되기 때문에, 대형 기업의 주식 가격 변동이 지수에 더 큰 영향을 미칩니다.
#
# 코스피 지수는 경제 전반의 건강 상태와 시장 투자 심리를 반영하는 지표로 자주 사용되며, 이를 통해 투자자들은 시장 동향을 파악하고, 투자 결정을 내리는 데 큰 도움이 됩니다.
#
# ETF(상장지수펀드)와 전통적인 펀드는 여러 면에서 차이가 있습니다. 아래에 주요한 차이점들을 정리해 드리겠습니다.
#
# 1. **거래 방식**:
#    - **ETF**: 주식처럼 거래소에서 자유롭게 사고팔 수 있습니다. 거래 시간 동안 실시간 가격으로 거래가 이루어집니다.
#    - **펀드**: 통상적으로 하루 한 번, 시장 종료 후에 정해진 NAV(순자산가치)로 거래됩니다. 투자자는 매입 또는 환매 요청을 하루 종일 할 수 있으나, 실제 거래는 하루가 끝난 후 이루어집니다.
#
# 2. **비용**:
#    - **ETF**: 대개 관리 수수료가 낮고, 거래를 할 때마다 주식처럼 브로커 수수료가 발생할 수 있습니다.
#    - **펀드**: 관리 수수료가 더 높을 수 있으며, 판매 수수료(LOAD)나 기타 관리 비용이 부과될 수 있습니다.
#
# 3. **투자 구조**:
#    - **ETF**: 주식 또는 자산의 인덱스를 추종하여 구성됩니다. 특정 자산군이나 지수를 모방하여 다양성을 제공합니다.
#    - **펀드**: 액티브 또는 패시브 방식으로 운용될 수 있으며, 펀드 매니저가 보다 적극적으로 투자를 관리합니다.
#
# 4. **세금 효율성**:
#    - **ETF**: 세금 효율성이 좋습니다. 매매가 주식처럼 이루어져야 하므로 자본 이득에 대한 세금을 즉시 납부할 필요가 없습니다.
#    - **펀드**: 펀드 내에서 자산 매매가 이루어질 때 실현된 이익에 대해 세금이 발생할 수 있어, 투자자가 예상치 못한 세금 부담을 느낄 수 있습니다.
#
# 5. **투자 최소금액**:
#    - **ETF**: 주식처럼 주 단위로 거래되기 때문에, 최소 투자 금액은 한 주의 가격에 해당합니다.
#    - **펀드**: 보통 최소 투자 금액이 설정되어 있으며, 이에 따라 일정 금액 이상에서만 투자할 수 있습니다.
#
# 이러한 차이점들을 고려하여 개인의 투자 목표와 스타일에 맞는 금융 상품을 선택하는 것이 중요합니다.

# %%
# stream() - 실시간 스트리밍 출력 (토큰 단위로 출력)
for chunk in llm.stream("환율이 수출 기업에 미치는 영향은?"):
    print(chunk.content, end="", flush=True)
# Out:
# 환율은 수출 기업에 여러 가지 방식으로 영향을 미칩니다. 주요 영향 요소는 다음과 같습니다:
#
# 1. **경쟁력**: 환율이 하락(즉, 자국 통화가 약세일 경우)하면, 해당 국가의 상품은 외국 시장에서 상대적으로 저렴해져 수출 경쟁력이 향상됩니다. 반대로, 환율이 상승하면 수출 제품의 가격이 비싸져 경쟁력이 약화될 수 있습니다.
#
# 2. **수익성**: 외화를 통해 수출한 기업은 외환 수익을 얻습니다. 따라서 환율이 유리한 방향으로 변하면 수익성이 증가하지만, 불리한 방향으로 변할 경우 수익이 줄어들 수 있습니다.
#
# 3. **계약 체결 및 가격 설정**: 수출 기업은 환율 변동에 따라 해외 바이어와의 가격 합의에서 불리한 입장에 놓일 수 있습니다. 환율 변동을 반영하여 가격을 조정하지 않으면 손실을 볼 수 있습니다.
#
# 4. **원가 및 자재 가격**: 수출 기업이 해외에서 원자재를 구매하는 경우, 환율이 상승하면 원자재 비용이 증가해 결과적으로 생산 비용이 높아질 수 있습니다. 이는 중간재나 원자재를 수입하여 최종 제품을 생산하는 기업에 직접적인 영향을 미칩니다.
#
# 5. **헤지 전략 필요성**: 환율 변동 리스크로 인해 수출 기업들은 헤지(hedging) 전략을 세우는 것이 필요할 수 있습니다. 이는 환율 상승이나 하락에 대비하여 손실을 최소화하려는 방안입니다.
#
# 6. **시장 다양화**: 수출 기업은 특정 국가나 지역에 의존하지 않기 위해 시장을 다변화하는 전략을 취할 수 있습니다. 환율이 불안정한 시장을 피하거나, 다양한 통화를 활용하여 리스크를 분산할 수 있습니다.
#
# 결론적으로, 환율은 수출 기업의 경영 전략과 수익성에 직접적인 영향을 미치며, 기업들은 이러한 변동성을 관리하기 위한 다양한 전략을 강구할 필요가 있습니다.

# %%
# 여기만 바꾸면 됩니다
question = "환율이 수출 기업에 미치는 영향은?"

response = llm.invoke(question)
print(response.content)
# Out:
# 환율은 수출 기업에 여러 가지 중요한 영향을 미칩니다. 다음은 그 주요한 영향 요소들입니다:
#
# 1. **제품 가격 경쟁력**: 환율이 하락(자국 통화 강세)하면 자국 제품의 해외 가격이 상승하게 되어, 외국 시장에서 경쟁력이 떨어질 수 있습니다. 반대로, 환율이 상승(자국 통화 약세)하면 자국 제품의 가격이 외국에서 낮아져 수출 경쟁력이 높아질 수 있습니다.
#
# 2. **수익성 변화**: 환율 변동은 수출 기업의 수익성에 직접적인 영향을 줍니다. 예를 들어, 천 원을 받고 수출한 상품이 달러로 환산될 때, 환율이 상승하면 외화로 환산된 수익이 증가하게 됩니다. 반면, 환율이 하락하면 수익이 줄어들 수 있습니다.
#
# 3. **계약 체결 영향**: 환율 변동이 클 경우, 외환 리스크를 관리하기 위해 수출 계약에서 환율을 고정하거나 헤지 옵션을 사용하는 기업들이 있습니다. 이는 수출 기업의 계약 체결 방식이나 판매 전략에 영향을 미칩니다.
#
# 4. **원자재 비용**: 수출 기업이 사용하는 원자재나 부품의 구매 비용도 환율에 영향을 받을 수 있습니다. 일반적으로 수출 기업이 외국에서 원자재를 구매할 경우, 자국 통화의 가치가 하락하면 원자재 비용이 상승하게 됩니다.
#
# 5. **국제 경제 환경**: 환율은 국제 경제 상황과 밀접하게 연결되어 있으며, 다른 국가의 산업 경쟁력에도 영향을 미칩니다. 특정 국가의 환율이 급격히 변동하면 글로벌 공급망이나 고객 수요에도 영향을 줄 수 있습니다.
#
# 6. **정부 정책**: 환율 변동에 따라 정부의 통화 정책 및 외환 정책도 달라질 수 있으며, 이는 수출 기업에 간접적인 영향을 미칠 수 있습니다.
#
# 결론적으로, 환율은 수출 기업의 운영에 큰 영향을 미치며, 이를 효과적으로 관리하는 것은 기업의 경쟁력 유지에 중요한 요소입니다.

# %%
questions = [
    "금리 인상이 부동산에 미치는 영향은?",
    "달러 강세일 때 유리한 업종은?",
    "인플레이션과 금리의 관계는?",
]

responses = llm.batch(questions)
for q, r in zip(questions, responses):
    print(f"Q: {q}")
    print(f"A: {r.content}")
    print("-" * 50)
# Out:
# Q: 금리 인상이 부동산에 미치는 영향은?
# A: 금리 인상은 부동산 시장에 여러 가지 중요한 영향을 미칩니다. 여기 몇 가지 주요 영향을 설명하겠습니다.
#
# 1. **차입 비용 증가**: 금리가 상승하면 주택담보대출과 같은 대출의 이자율이 높아집니다. 이는 주택 구매자들의 차입 비용을 증가시켜 주택을 구입하기 어려워지게 만들고, 결과적으로 주택 수요가 감소할 수 있습니다.
#
# 2. **주택 가격 하락**: 수요가 줄어들면 주택 가격도 하락할 수 있습니다. 특히 높은 가격의 주택을 사려는 수요가 감소하면, 전체적인 시장 가격에 부정적인 영향을 미칠 수 있습니다.
#
# 3. **임대 시장에 대한 영향**: 금리 인상은 주택 구매자 수를 줄이는 것뿐만 아니라, 사람들이 주택을 구매 대신 임대할 가능성을 높입니다. 이는 임대 수요를 증가시킬 수 있으나, 동시에 임대료 인상이 제한될 수도 있습니다.
#
# 4. **투자자의 입장 변화**: 금리가 인상될 경우, 부동산 투자에 대한 매력이 감소할 수 있습니다. 투자자들은 더 높은 대출 비용과 불확실한 수익률에 불안해할 수 있어, 부동산 시장에서 손을 떼는 경향을 보일 수 있습니다.
#
# 5. **건축 및 개발 지연**: 부동산 개발 프로젝트의 경우, 높은 금리는 프로젝트 자금 조달에 영향을 미쳐 신규 건축이나 개발이 지연되거나 축소될 수 있습니다. 이는 장기적으로 시장 공급에 영향을 미칠 수 있습니다.
#
# 6. **경제 전반의 영향**: 금리 인상은 소비자 지출에 영향을 미쳐 경제 전반에 부정적인 영향을 줄 수 있습니다. 경제가 둔화되면 부동산 시장도 더 큰 타격을 받을 수 있습니다.
#
# 결론적으로, 금리 인상은 부동산 시장에 다각적인 영향을 미치며, 주택 수요와 공급, 가격 등에 변화를 일으킬 수 있습니다. 시장의 반응은 다양한 요소에 따라 달라질 수 있기 때문에, 이러한 변화를 종합적으로 고려하는 것이 중요합니다.
# --------------------------------------------------
# Q: 달러 강세일 때 유리한 업종은?
# A: 달러 강세가 지속될 때 유리한 업종은 다음과 같습니다:
#
# 1. **수출 업체**: 강한 달러는 해외 시장에서 미국 제품의 가격을 상대적으로 높게 만들 수 있지만, 원자재나 생산 비용이 해외에서 공수되는 경우 원가 절감 효과가 있을 수 있습니다.
#
# 2. **항공사**: 항공사는 외환 거래에서 기름을 구매할 때 강한 달러 덕분에 연료 비용이 낮아질 수 있습니다. 이는 수익성 개선으로 이어질 수 있습니다.
#
# 3. **소비재 업체**: 외국에서 원자재나 부품을 수입하는 기업들은 강한 달러 혜택을 받아 비용 절감 효과를 누릴 수 있습니다.
#
# 4. **기술 기업**: 많은 기술 기업들이 해외에서 수익을 창출하는 경우가 많습니다. 그러나 강한 달러가 해외 수익을 환전할 때 유리하지 않을 수 있으므로, 해외 매출 비중이 낮거나 국내 판매가 중심인 기업들이 상대적으로 긍정적인 영향을 받을 수 있습니다.
#
# 5. **금융 서비스**: 해외 투자 및 거래를 많이 하는 금융기관들은 강한 달러가 유리하게 작용할 수 있습니다.
#
# 반대로, 달러 강세는 해외에서 수입되는 상품의 가격을 인하하여 경쟁력을 떨어뜨릴 수 있는 업종도 존재하므로, 업종의 특성을 고려해야 합니다.
# --------------------------------------------------
# Q: 인플레이션과 금리의 관계는?
# A: 인플레이션과 금리는 밀접한 관계가 있습니다. 일반적으로 다음과 같은 방식으로 서로 영향을 미칩니다.
#
# 1. **인플레이션 상승 → 금리 상승**: 인플레이션이 높아지면 중앙은행은 경제 과열을 방지하고 물가 안정을 위해 금리를 인상하는 경향이 있습니다. 금리가 높아지면 대출 비용이 증가하고 소비와 투자를 억제하게 되어 인플레이션 압력을 완화하는 데 도움이 됩니다.
#
# 2. **금리 상승 → 소비 및 투자 감소**: 금리가 오르면 기업과 개인의 대출 비용이 높아져 소비와 투자가 줄어들게 됩니다. 이는 경제 성장률을 둔화시키고 궁극적으로는 인플레이션을 낮추는 데 기여할 수 있습니다.
#
# 3. **인플레이션 안정 → 금리 안정**: 반대로 인플레이션이 안정적이고 낮은 수준을 유지하면 중앙은행은 금리를 낮출 수 있습니다. 낮은 금리는 경제 성장을 촉진하고 소비 및 투자를 증가시키는 데 도움이 될 수 있습니다.
#
# 4. **기대 인플레이션**: 시장의 인플레이션 전망도 금리에 영향을 미칩니다. 만약 사람들이 앞으로 인플레이션이 상승할 것이라고 기대한다면, 그에 따라 금리가 상승할 가능성이 높습니다.
#
# 따라서, 인플레이션과 금리는 서로 상호작용하며 경제 전반에 큰 영향을 미치는 중요한 요소입니다.
# --------------------------------------------------

# %%
import asyncio
import time
# from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-4o-mini")

questions = [f"주식 투자 팁 {i}번째" for i in range(10)]

# 비동기 병렬 처리
async def invoke_async(question): #각 프롬프트 1개 처리
    response = await llm.ainvoke(question)
    return response.content

async def invoke_parallel(questions): #다수의 프롬프트 목록을 처리 
    tasks = [invoke_async(q) for q in questions]
    return await asyncio.gather(*tasks)

# %%
res = await invoke_async(questions[0])
print(res)
# Out:
# 주식 투자에 대한 첫 번째 팁은 "기초 지식을 쌓는 것"입니다. 주식 투자에 성공하려면 먼저 기본적인 개념과 원리를 이해하는 것이 중요합니다. 이를 통해 시장의 움직임을 더 잘 분석하고, 자신에게 맞는 투자 전략을 세울 수 있습니다.
#
# 주식 투자에 대한 기초 지식을 쌓기 위해 다음과 같은 사항을 고려해보세요:
#
# 1. **주식의 기본 개념 이해**: 주식이 무엇인지, 어떻게 거래되는지, 주식 시장의 구조에 대해 배우세요.
#
# 2. **재무제표 분석**: 기업의 재무제표(손익계산서, 대차대조표 등)를 읽고 이해하는 법을 익히세요. 이는 기업의 건강성을 평가하는 데 중요한 요소입니다.
#
# 3. **투자 전략 연구**: 가치 투자, 성장 투자, 배당 투자 등 다양한 투자 전략에 대해 알아보세요. 각 전략의 장단점을 이해하고 자신에게 맞는 방법을 선택하세요.
#
# 4. **시장 동향 파악**: 경제 지표, 금리, 정치적 상황 등이 주식 시장에 미치는 영향을 배우고, 실시간으로 시장 소식을 팔로우하세요.
#
# 5. **모의 투자 경험**: 실제 돈을 투자하기 전에 모의 투자 플랫폼을 통해 경험을 쌓아보세요.
#
# 기초를 탄탄히 한 후에 투자 결정을 내리는 것이 좋습니다.

# %%
# 비동기 실행 시간 측정
start = time.perf_counter()
results = await invoke_parallel(questions)
end = time.perf_counter()
print(f"비동기 처리: {end - start:.2f}초")   # 약 5~6초
# Out:
# 비동기 처리: 6.91초

# %%
# 동기 실행 시간 측정
start = time.perf_counter()
for q in questions:
    response = llm.invoke(q) #동기 호출
end = time.perf_counter()
print(f"동기 처리: {end - start:.2f}초")     # 약 40~50초
# Out:
# 동기 처리: 55.60초

# %%
results
# Out:
# ['주식 투자에 대한 0번째 팁은 "조사와 학습"입니다. 주식 시장에 투자하기 전에 기본적인 원칙과 개별 기업에 대해 충분히 연구하고 학습하는 것이 중요합니다. \n\n1. **기본적인 개념 이해**: 주식이란 무엇인지, 주식 시장이 어떻게 운영되는지에 대한 기초 지식을 습득하세요.\n2. **기업 분석**: 투자하고자 하는 기업의 재무 상태, 성장 가능성, 경쟁 우위 등을 분석하세요. 재무 제표, 뉴스, 산업 동향 등을 참고하는 것이 도움이 됩니다.\n3. **투자 전략 수립**: 장기 투자, 단기 매매, 가치 투자, 성장 투자 등 자신에게 맞는 전략을 세우세요.\n4. **심리 관리**: 투자하면서 감정이 개입되지 않도록 하고, 냉정하게 판단하는 자세를 유지하세요.\n\n기본을 탄탄히 하여 신뢰할 수 있는 결정을 내리는 것이 성공적인 투자로 이어질 수 있습니다.',
#  '주식 투자에서 첫 번째 팁은 **철저한 리서치**입니다. 투자할 기업이나 산업에 대한 충분한 정보를 수집하고 분석하는 것이 매우 중요합니다. \n\n1. **재무제표 분석**: 기업의 재무상태표, 손익계산서, 현금흐름표 등을 통해 기업의 재무 건전성을 파악하세요.\n2. **산업 동향**: 해당 산업의 성장 가능성 및 동향을 연구하여 시장에서의 위치를 평가합니다.\n3. **경쟁 분석**: 같은 산업 내 경쟁사들과 비교해 해당 기업의 경쟁력을 살펴보세요.\n4. **뉴스 및 리포트**: 경제 뉴스, 전문가 리포트 등을 통해 최신 정보와 시장의 변화를 지속적으로 체크합니다.\n\n철저한 리서치는 성공적인 투자에 큰 영향을 미치므로, 시간을 들여 잘 준비하는 것이 중요합니다.',
#  '주식 투자에 대한 두 번째 팁은 **장기 투자 전략을 고려하십시오**입니다.\n\n1. **시장 변동성에 흔들리지 않기**: 주식 시장은 단기적으로 큰 변동을 보일 수 있습니다. 이러한 변동성에 흔들리지 않고, 기업의 기본적인 가치와 장기적인 성장 가능성에 주목하는 것이 중요합니다.\n\n2. **기업 분석**: 투자할 기업의 재무제표, 성장 가능성, 경쟁력, 산업 동향 등을 철저히 분석하십시오. 오래 지속할 수 있는 좋은 기업에 투자하는 것이 장기적으로 안정적인 수익을 가져다 줄 확률이 높습니다.\n\n3. **분산 투자**: 여러 종목에 분산 투자하여 특정 주식의 하락 위험을 줄이세요. 다양한 산업과 시장에 분산하는 것이 좋습니다.\n\n4. **정기적인 리뷰**: 투자한 주식의 성과를 정기적으로 리뷰하고, 시장 변화에 맞춰 포트폴리오를 조정하는 것도 중요합니다. \n\n이런 전략을 통해 초 단기적인 이익보다는 안정적인 성장을 추구하는 것이 장기적인 성공에 도움이 될 수 있습니다.',
#  '주식 투자에 대한 세 번째 팁은 **장기 투자 관점 유지**입니다.\n\n주식 시장은 단기적으로 변동성이 크고 예측하기 어렵습니다. 따라서 단기적인 가격 변동에 신경 쓰기보다는, 장기적인 성장 가능성이 있는 기업에 투자하는 것이 중요합니다. 이러한 접근 방식은 다음과 같은 이점을 제공합니다:\n\n1. **복리 효과 활용**: 시간이 지남에 따라 투자 수익이 재투자되면서 자산이 더욱 크게 성장할 수 있습니다.\n2. **감정의 통제**: 단기적인 시장 변동에 휘둘리지 않고, 투자에 대한 신뢰를 유지할 수 있습니다.\n3. **시장 타이밍 피하기**: 시장의 최적의 진입 시점을 정확히 예측하는 것은 매우 어렵습니다. 지속적인 투자로 시간 분산을 통해 평균 매입 단가를 낮출 수 있습니다.\n\n투자 목표와 계획을 세우고, 이에 맞춰 장기적으로 인내심을 가지고 투자하는 것이 성공적인 주식 투자로 이어질 수 있습니다.',
#  '주식 투자에 대한 네 번째 팁은 **장기 투자 전략을 고려하라**입니다.\n\n### 장기 투자 전략 고려하기\n\n1. **시장 변동성에 흔들리지 않기**: 주식 시장은 단기적으로 큰 변동성을 보일 수 있습니다. 하지만 장기적으로는 경제 성장에 따라 상승하는 경향이 있습니다. 따라서 단기적인 가격 변동에 신경 쓰기보다는 장기적인 성장 가능성을 염두에 두고 투자하는 것이 중요합니다.\n\n2. **재무 건전성 분석**: 장기 투자를 고려할 때, 기업의 재무 상태가 무엇보다 중요합니다. 안정적인 수익성과 적정한 부채 비율을 가진 기업에 투자하면 장기적인 안정성을 기대할 수 있습니다.\n\n3. **배당주 투자**: 배당금을 지속적으로 지급하는 기업에 투자하면 안정적인 수익을 얻을 수 있습니다. 배당금은 주가 상승뿐만 아니라 정기적인 소득을 제공하므로 장기 투자에 유리합니다.\n\n4. **분산 투자**: 다양한 산업과 지역에 걸쳐 포트폴리오를 분산시키면 리스크를 줄이고 안정적인 수익을 기대할 수 있습니다. 여러 자산에 투자하여 특정 자산의 성과에 의한 영향을 최소화하세요.\n\n5. **정기적인 포트폴리오 점검**: 일정 주기로 투자 포트폴리오를 점검하고 필요에 따라 조정하는 것이 필요합니다. 시장 상황이나 개인의 투자 목표에 따라 리밸런싱을 고려하세요.\n\n장기 투자 전략은 시간이 지남에 따라 안정적인 수익을 가져다 줄 수 있는 효과적인 접근 방법입니다.',
#  '주식 투자에 대한 다섯 번째 팁은 **감정 관리**입니다. 투자에서는 감정이 매우 큰 영향을 미칠 수 있습니다. 다음은 감정 관리를 위한 몇 가지 방법입니다:\n\n1. **장기적인 관점 유지**: 단기 변동성이 크더라도 장기적인 투자 목표에 집중하세요. 주가의 일시적인 하락에 과도하게 반응하지 않도록 합니다.\n\n2. **분산 투자**: 여러 종목에 투자함으로써 위험을 분산시키고, 특정 종목의 성과에 대한 감정적 반응을 줄이는 데 도움이 됩니다.\n\n3. **목표 설정**: 명확한 투자 목표를 설정하고, 그에 따라 계획을 세우세요. 목표를 잃지 않으면 감정에 휘둘리지 않을 수 있습니다.\n\n4. **정기적인 점검**: 주기적으로 포트폴리오를 점검하되, 감정에 따라 불필요한 거래를 하지 않도록 주의합니다.\n\n5. **정보에 의존하기**: 감정적 결정 대신 데이터와 분석에 기반한 결정을 내리도록 합니다. 신뢰할 수 있는 정보를 바탕으로 투자 결정을 하는 것이 중요합니다.\n\n이렇게 감정을 잘 관리하면 더 나은 투자 판단을 할 수 있게 될 것입니다.',
#  '주식 투자에 대한 여섯 번째 팁은 **장기적인 관점을 유지하라**입니다. \n\n주식 시장은 단기적으로 변동성이 크고 예측하기 어려운 경우가 많습니다. 따라서 단기적인 가격 변동에 신경 쓰기보다는, 투자의 목표를 명확히 하고 이를 기반으로 장기적인 투자 전략을 세우는 것이 중요합니다. 기업의 펀더멘털, 시장 트렌드, 경제 전반의 흐름 등을 분석하고, 이러한 요소들이 시간이 지남에 따라 어떻게 변화할지를 고려하면서 투자 결정을 내리는 것이 좋습니다.\n\n장기 투자 시 장기적으로 우량 기업의 주식이 상승할 가능성이 더 높다는 점을 기억하세요. 또한, 주식 시장의 상승과 하락을 견디는 인내심 또한 필요합니다. 이렇게 함으로써 시장의 일시적인 변동에 흔들리지 않고 보다 안정적인 수익을 기대할 수 있습니다.',
#  '주식 투자에 관한 7번째 팁은 다음과 같습니다:\n\n**기대 수익률과 위험을 이해하라**  \n투자 결정을 내리지 전에 특정 주식이나 투자 전략의 기대 수익률과 관련된 위험을 명확히 이해하는 것이 중요합니다. 투자자가 원하는 수익률과 그에 따른 위험 수준을 비교하여, 자신의 투자 성향에 맞는 결정을 내릴 수 있도록 해야 합니다. \n\n이와 함께, 포트폴리오의 다각화도 고려해보세요. 다양한 산업과 자산군에 투자하면 특정 산업이나 기업의 부진으로 인한 리스크를 줄일 수 있습니다. \n\n이 팁을 통해 보다 심도 있게 시장을 분석하고, 자신에게 맞는 전략을 개발해 나가기를 바랍니다.',
#  '주식 투자 팁 8번째는 **Diversification (다양화)**입니다.\n\n주식 투자에서 다양화는 리스크를 줄이고 안정성을 높이는 중요한 전략입니다. 여러 산업과 기업에 투자함으로써 특정 기업이나 산업의 부진으로 인한 손실을 줄일 수 있습니다. 다음은 다양화를 효과적으로 수행하는 방법입니다:\n\n1. **산업 분산**: 서로 다른 산업에 속하는 주식에 투자하세요. 예를 들어, 기술, 헬스케어, 소비재 등 다양한 산업에 분산 투자합니다.\n\n2. **자산 클래스 분산**: 주식뿐만 아니라 채권, 부동산 투자 신탁(REITs), 원자재 등 다양한 자산 클래스에 투자하여 리스크를 분산시킵니다.\n\n3. **지역 분산**: 국내 주식뿐만 아니라 해외 주식에도 투자해 보세요. 글로벌 경제의 영향을 고려하여 다양한 국가의 시장에 참여합니다.\n\n4. **다양한 투자 스타일**: 장기 투자, 단기 투자, 성장주, 가치주 등 다양한 투자 스타일을 고려해 포트폴리오를 구성합니다.\n\n다양화를 통해 특정 자산이나 투자에서 발생할 수 있는 리스크를 줄이고, 보다 안정적인 수익을 추구할 수 있습니다. 하지만 과도한 다양화는 관리의 어려움을 초래할 수 있으니 적절한 수준에서 유지하는 것이 중요합니다.',
#  '주식 투자 팁 9번째는 **장기적인 시각을 갖자**입니다.\n\n주식 시장은 단기적으로 많은 변동성이 있으며, 가격이 급격하게 오르거나 내릴 수 있습니다. 그러나 기업의 기본적인 가치와 성장 가능성에 집중하고 장기적으로 투자하는 것이 중요합니다. 다음은 몇 가지 구체적인 방법입니다.\n\n1. **기본 분석**: 기업의 재무제표, 수익 성장, 시장 점유율 등을 분석하여 장기적인 투자 가치를 평가하세요.\n\n2. **분산 투자**: 여러 업종과 자산에 투자하여 위험을 분산시키세요. 특정 주식의 하락이 당신의 전체 포트폴리오에 미치는 영향을 줄일 수 있습니다.\n\n3. **정기적인 검토**: 투자한 종목을 주기적으로 검토하고, 경제 상황이나 기업의 변화에 맞춰 조정하세요.\n\n4. **투자 목표 설정**: 명확한 투자 목표를 설정하고 그 목표에 맞춰 계획적으로 투자하세요. 단기적인 변동에 흔들리지 않도록 하세요.\n\n5. **정신적인 준비**: 주식 시장의 변동성에 심리적으로 대비하고, 감정을 배제한 결정을 내리는 연습을 하세요.\n\n장기적인 투자 전략은 단기적인 시세 변동에 민감하지 않게 만들어 주며, 전반적인 수익률을 향상시킬 수 있습니다.']

# %%
for index, content in enumerate(results):
  print(f"{index}, content:{content}")
# Out:
# 0, content:주식 투자에 대한 0번째 팁은 "조사와 학습"입니다. 주식 시장에 투자하기 전에 기본적인 원칙과 개별 기업에 대해 충분히 연구하고 학습하는 것이 중요합니다.
#
# 1. **기본적인 개념 이해**: 주식이란 무엇인지, 주식 시장이 어떻게 운영되는지에 대한 기초 지식을 습득하세요.
# 2. **기업 분석**: 투자하고자 하는 기업의 재무 상태, 성장 가능성, 경쟁 우위 등을 분석하세요. 재무 제표, 뉴스, 산업 동향 등을 참고하는 것이 도움이 됩니다.
# 3. **투자 전략 수립**: 장기 투자, 단기 매매, 가치 투자, 성장 투자 등 자신에게 맞는 전략을 세우세요.
# 4. **심리 관리**: 투자하면서 감정이 개입되지 않도록 하고, 냉정하게 판단하는 자세를 유지하세요.
#
# 기본을 탄탄히 하여 신뢰할 수 있는 결정을 내리는 것이 성공적인 투자로 이어질 수 있습니다.
# 1, content:주식 투자에서 첫 번째 팁은 **철저한 리서치**입니다. 투자할 기업이나 산업에 대한 충분한 정보를 수집하고 분석하는 것이 매우 중요합니다.
#
# 1. **재무제표 분석**: 기업의 재무상태표, 손익계산서, 현금흐름표 등을 통해 기업의 재무 건전성을 파악하세요.
# 2. **산업 동향**: 해당 산업의 성장 가능성 및 동향을 연구하여 시장에서의 위치를 평가합니다.
# 3. **경쟁 분석**: 같은 산업 내 경쟁사들과 비교해 해당 기업의 경쟁력을 살펴보세요.
# 4. **뉴스 및 리포트**: 경제 뉴스, 전문가 리포트 등을 통해 최신 정보와 시장의 변화를 지속적으로 체크합니다.
#
# 철저한 리서치는 성공적인 투자에 큰 영향을 미치므로, 시간을 들여 잘 준비하는 것이 중요합니다.
# 2, content:주식 투자에 대한 두 번째 팁은 **장기 투자 전략을 고려하십시오**입니다.
#
# 1. **시장 변동성에 흔들리지 않기**: 주식 시장은 단기적으로 큰 변동을 보일 수 있습니다. 이러한 변동성에 흔들리지 않고, 기업의 기본적인 가치와 장기적인 성장 가능성에 주목하는 것이 중요합니다.
#
# 2. **기업 분석**: 투자할 기업의 재무제표, 성장 가능성, 경쟁력, 산업 동향 등을 철저히 분석하십시오. 오래 지속할 수 있는 좋은 기업에 투자하는 것이 장기적으로 안정적인 수익을 가져다 줄 확률이 높습니다.
#
# 3. **분산 투자**: 여러 종목에 분산 투자하여 특정 주식의 하락 위험을 줄이세요. 다양한 산업과 시장에 분산하는 것이 좋습니다.
#
# 4. **정기적인 리뷰**: 투자한 주식의 성과를 정기적으로 리뷰하고, 시장 변화에 맞춰 포트폴리오를 조정하는 것도 중요합니다.
#
# 이런 전략을 통해 초 단기적인 이익보다는 안정적인 성장을 추구하는 것이 장기적인 성공에 도움이 될 수 있습니다.
# 3, content:주식 투자에 대한 세 번째 팁은 **장기 투자 관점 유지**입니다.
#
# 주식 시장은 단기적으로 변동성이 크고 예측하기 어렵습니다. 따라서 단기적인 가격 변동에 신경 쓰기보다는, 장기적인 성장 가능성이 있는 기업에 투자하는 것이 중요합니다. 이러한 접근 방식은 다음과 같은 이점을 제공합니다:
#
# 1. **복리 효과 활용**: 시간이 지남에 따라 투자 수익이 재투자되면서 자산이 더욱 크게 성장할 수 있습니다.
# 2. **감정의 통제**: 단기적인 시장 변동에 휘둘리지 않고, 투자에 대한 신뢰를 유지할 수 있습니다.
# 3. **시장 타이밍 피하기**: 시장의 최적의 진입 시점을 정확히 예측하는 것은 매우 어렵습니다. 지속적인 투자로 시간 분산을 통해 평균 매입 단가를 낮출 수 있습니다.
#
# 투자 목표와 계획을 세우고, 이에 맞춰 장기적으로 인내심을 가지고 투자하는 것이 성공적인 주식 투자로 이어질 수 있습니다.
# 4, content:주식 투자에 대한 네 번째 팁은 **장기 투자 전략을 고려하라**입니다.
#
# ### 장기 투자 전략 고려하기
#
# 1. **시장 변동성에 흔들리지 않기**: 주식 시장은 단기적으로 큰 변동성을 보일 수 있습니다. 하지만 장기적으로는 경제 성장에 따라 상승하는 경향이 있습니다. 따라서 단기적인 가격 변동에 신경 쓰기보다는 장기적인 성장 가능성을 염두에 두고 투자하는 것이 중요합니다.
#
# 2. **재무 건전성 분석**: 장기 투자를 고려할 때, 기업의 재무 상태가 무엇보다 중요합니다. 안정적인 수익성과 적정한 부채 비율을 가진 기업에 투자하면 장기적인 안정성을 기대할 수 있습니다.
#
# 3. **배당주 투자**: 배당금을 지속적으로 지급하는 기업에 투자하면 안정적인 수익을 얻을 수 있습니다. 배당금은 주가 상승뿐만 아니라 정기적인 소득을 제공하므로 장기 투자에 유리합니다.
#
# 4. **분산 투자**: 다양한 산업과 지역에 걸쳐 포트폴리오를 분산시키면 리스크를 줄이고 안정적인 수익을 기대할 수 있습니다. 여러 자산에 투자하여 특정 자산의 성과에 의한 영향을 최소화하세요.
#
# 5. **정기적인 포트폴리오 점검**: 일정 주기로 투자 포트폴리오를 점검하고 필요에 따라 조정하는 것이 필요합니다. 시장 상황이나 개인의 투자 목표에 따라 리밸런싱을 고려하세요.
#
# 장기 투자 전략은 시간이 지남에 따라 안정적인 수익을 가져다 줄 수 있는 효과적인 접근 방법입니다.
# 5, content:주식 투자에 대한 다섯 번째 팁은 **감정 관리**입니다. 투자에서는 감정이 매우 큰 영향을 미칠 수 있습니다. 다음은 감정 관리를 위한 몇 가지 방법입니다:
#
# 1. **장기적인 관점 유지**: 단기 변동성이 크더라도 장기적인 투자 목표에 집중하세요. 주가의 일시적인 하락에 과도하게 반응하지 않도록 합니다.
#
# 2. **분산 투자**: 여러 종목에 투자함으로써 위험을 분산시키고, 특정 종목의 성과에 대한 감정적 반응을 줄이는 데 도움이 됩니다.
#
# 3. **목표 설정**: 명확한 투자 목표를 설정하고, 그에 따라 계획을 세우세요. 목표를 잃지 않으면 감정에 휘둘리지 않을 수 있습니다.
#
# 4. **정기적인 점검**: 주기적으로 포트폴리오를 점검하되, 감정에 따라 불필요한 거래를 하지 않도록 주의합니다.
#
# 5. **정보에 의존하기**: 감정적 결정 대신 데이터와 분석에 기반한 결정을 내리도록 합니다. 신뢰할 수 있는 정보를 바탕으로 투자 결정을 하는 것이 중요합니다.
#
# 이렇게 감정을 잘 관리하면 더 나은 투자 판단을 할 수 있게 될 것입니다.
# 6, content:주식 투자에 대한 여섯 번째 팁은 **장기적인 관점을 유지하라**입니다.
#
# 주식 시장은 단기적으로 변동성이 크고 예측하기 어려운 경우가 많습니다. 따라서 단기적인 가격 변동에 신경 쓰기보다는, 투자의 목표를 명확히 하고 이를 기반으로 장기적인 투자 전략을 세우는 것이 중요합니다. 기업의 펀더멘털, 시장 트렌드, 경제 전반의 흐름 등을 분석하고, 이러한 요소들이 시간이 지남에 따라 어떻게 변화할지를 고려하면서 투자 결정을 내리는 것이 좋습니다.
#
# 장기 투자 시 장기적으로 우량 기업의 주식이 상승할 가능성이 더 높다는 점을 기억하세요. 또한, 주식 시장의 상승과 하락을 견디는 인내심 또한 필요합니다. 이렇게 함으로써 시장의 일시적인 변동에 흔들리지 않고 보다 안정적인 수익을 기대할 수 있습니다.
# 7, content:주식 투자에 관한 7번째 팁은 다음과 같습니다:
#
# **기대 수익률과 위험을 이해하라**
# 투자 결정을 내리지 전에 특정 주식이나 투자 전략의 기대 수익률과 관련된 위험을 명확히 이해하는 것이 중요합니다. 투자자가 원하는 수익률과 그에 따른 위험 수준을 비교하여, 자신의 투자 성향에 맞는 결정을 내릴 수 있도록 해야 합니다.
#
# 이와 함께, 포트폴리오의 다각화도 고려해보세요. 다양한 산업과 자산군에 투자하면 특정 산업이나 기업의 부진으로 인한 리스크를 줄일 수 있습니다.
#
# 이 팁을 통해 보다 심도 있게 시장을 분석하고, 자신에게 맞는 전략을 개발해 나가기를 바랍니다.
# 8, content:주식 투자 팁 8번째는 **Diversification (다양화)**입니다.
#
# 주식 투자에서 다양화는 리스크를 줄이고 안정성을 높이는 중요한 전략입니다. 여러 산업과 기업에 투자함으로써 특정 기업이나 산업의 부진으로 인한 손실을 줄일 수 있습니다. 다음은 다양화를 효과적으로 수행하는 방법입니다:
#
# 1. **산업 분산**: 서로 다른 산업에 속하는 주식에 투자하세요. 예를 들어, 기술, 헬스케어, 소비재 등 다양한 산업에 분산 투자합니다.
#
# 2. **자산 클래스 분산**: 주식뿐만 아니라 채권, 부동산 투자 신탁(REITs), 원자재 등 다양한 자산 클래스에 투자하여 리스크를 분산시킵니다.
#
# 3. **지역 분산**: 국내 주식뿐만 아니라 해외 주식에도 투자해 보세요. 글로벌 경제의 영향을 고려하여 다양한 국가의 시장에 참여합니다.
#
# 4. **다양한 투자 스타일**: 장기 투자, 단기 투자, 성장주, 가치주 등 다양한 투자 스타일을 고려해 포트폴리오를 구성합니다.
#
# 다양화를 통해 특정 자산이나 투자에서 발생할 수 있는 리스크를 줄이고, 보다 안정적인 수익을 추구할 수 있습니다. 하지만 과도한 다양화는 관리의 어려움을 초래할 수 있으니 적절한 수준에서 유지하는 것이 중요합니다.
# 9, content:주식 투자 팁 9번째는 **장기적인 시각을 갖자**입니다.
#
# 주식 시장은 단기적으로 많은 변동성이 있으며, 가격이 급격하게 오르거나 내릴 수 있습니다. 그러나 기업의 기본적인 가치와 성장 가능성에 집중하고 장기적으로 투자하는 것이 중요합니다. 다음은 몇 가지 구체적인 방법입니다.
#
# 1. **기본 분석**: 기업의 재무제표, 수익 성장, 시장 점유율 등을 분석하여 장기적인 투자 가치를 평가하세요.
#
# 2. **분산 투자**: 여러 업종과 자산에 투자하여 위험을 분산시키세요. 특정 주식의 하락이 당신의 전체 포트폴리오에 미치는 영향을 줄일 수 있습니다.
#
# 3. **정기적인 검토**: 투자한 종목을 주기적으로 검토하고, 경제 상황이나 기업의 변화에 맞춰 조정하세요.
#
# 4. **투자 목표 설정**: 명확한 투자 목표를 설정하고 그 목표에 맞춰 계획적으로 투자하세요. 단기적인 변동에 흔들리지 않도록 하세요.
#
# 5. **정신적인 준비**: 주식 시장의 변동성에 심리적으로 대비하고, 감정을 배제한 결정을 내리는 연습을 하세요.
#
# 장기적인 투자 전략은 단기적인 시세 변동에 민감하지 않게 만들어 주며, 전반적인 수익률을 향상시킬 수 있습니다.

# %%
from langchain_community.callbacks import get_openai_callback

with get_openai_callback() as callback:
    message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 길거리 음식은?")]
    response = llm.invoke(message)
    print(response.content)
    print(f"\n총 토큰: {callback.total_tokens}")
    print(f"프롬프트 토큰: {callback.prompt_tokens}")
    print(f"응답 토큰: {callback.completion_tokens}")
    print(f"비용(USD): ${callback.total_cost:.6f}")
# Out:
# 서울 광장시장에서 맛있는 길거리 음식으로는 여러 가지가 있지만, 특히 다음과 같은 음식들이 인기 있습니다:
#
# 1. **떡볶이**: 매콤달콤한 소스에 쫄깃한 떡이 어우러진 대표적인 스트리트 푸드입니다.
# 2. **오뎅**: 다양한 어묵이 다시 육수에 담겨 제공되며, 겨자 소스와 함께 먹는 것이 일반적입니다.
# 3. **순대**: 국내에서 인기 있는 찹쌀과 다양한 재료가 들어간 순대를 길거리에서 쉽게 찾을 수 있습니다.
# 4. **호떡**: 달콤한 시럽과 견과류가 들어간 전통 간식으로, 따뜻하게 구워져 제공됩니다.
# 5. **김밥**: 다양한 재료가 들어간 김밥도 손쉽게 먹을 수 있어 많은 사람들이 찾습니다.
#
# 각 상점마다 특색 있는 맛이 있으니 여러 곳을 돌아다니며 시식해보는 것도 좋은 경험이 될 것입니다!
#
# 총 토큰: 255
# 프롬프트 토큰: 20
# 응답 토큰: 235
# 비용(USD): $0.000144

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

llm = ChatOpenAI(model="gpt-4o-mini")

# 대화 시작
messages = [
    SystemMessage(content="당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다."),
    HumanMessage(content="삼성전자 주식을 지금 매수해도 될까요?")
]

response = llm.invoke(messages)
# messages.append(response)  # AI 응답을 히스토리에 추가

print(response.content)
# Out:
# 삼성전자 주식 매수 여부를 결정하기 위해 몇 가지 요소를 고려해야 합니다.
#
# 1. **기본적 분석**: 삼성전자의 재무 상태, 매출 성장률, 순이익, 배당금 지급 여부 등을 살펴보세요. 특히 최근 분기 실적 발표와 연간 가이던스가 중요합니다.
#
# 2. **산업 동향**: 반도체, 모바일, 디스플레이 등 삼성전자가 주력하고 있는 산업의 시장 전망을 분석하십시오. 글로벌 수요, 경쟁업체의 동향, 기술 혁신 등이 영향을 미칠 수 있습니다.
#
# 3. **기술적 분석**: 주가 차트를 분석하여 지지선 및 저항선, 이동평균선과 같은 기술적 지표를 확인해 보세요. 현재 주가가 어떤 위치에 있는지, 과매도 또는 과매수 상태인지도 중요합니다.
#
# 4. **경제 전반**: 금리, 인플레이션, 글로벌 경제 상황 등의 거시적 요인이 삼성전자에 미칠 영향을 고려해야 합니다.
#
# 5. **투자 목표**: 장기적으로 투자할 것인지, 단기적인 수익을 목표로 하는지에 따라 매수 결정을 달리해야 합니다.
#
# 주식 투자에는 위험이 따르므로, 이러한 요소들을 신중히 고려하고, 필요하다면 전문가의 조언을 받는 것이 좋습니다.

# %%
# 후속 질문 (이전 맥락 유지)
# messages.append(HumanMessage(content="그렇다면 목표 주가는 얼마로 보시나요?"))
messages1 = [
  SystemMessage(content="당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다."), HumanMessage(content="그렇다면 목표 주가는 얼마로 보시나요?")
]
response1 = llm.invoke(messages1)
print(response1.content)
# Out:
# 목표 주가는 특정 기업의 재무 상황, 시장 환경, 섹터 동향, 경쟁사 분석 등을 종합적으로 고려하여 결정됩니다. 어떤 특정 주식에 대한 목표 주가를 알고 싶으신 건가요? 해당 기업의 이름이나 티커(symbol)를 알려주시면 분석에 도움이 될 수 있습니다.

# %%
messages = [
    SystemMessage(content="당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다."),
    HumanMessage(content="삼성전자 주식을 지금 매수해도 될까요?")
]

response = llm.invoke(messages)
messages.append(response)
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식을 매수할지 고민할 때 고려해야 할 몇 가지 요소가 있습니다.\n\n1. **재무상태**: 삼성전자의 최근 재무제표를 분석해 보세요. 매출, 순이익, 부채비율 등의 지표가 양호한지 확인하는 것이 중요합니다.\n\n2. **시장 전망**: 반도체와 전자기기 산업의 현재 시장 동향과 전망을 살펴보세요. 특히, 반도체 공급망, 경쟁사와의 비교, 글로벌 경제 상황 등이 중요한 요소입니다.\n\n3. **주가 추세**: 최근 주가의 변동성과 기술적 분석을 통해 매수를 고려할 시점을 판단할 수 있습니다. 최근 주가가 하락세라면 매수 기회로 볼 수도 있지만, 하락 이유를 분석하는 것이 필요합니다.\n\n4. **장기적인 투자 전략**: 삼성전자가 장기적으로 안정성 있는 기업이라는 점을 고려할 때, 장기 투자 목표에 부합한다면 매수하는 것이 좋을 수 있습니다.\n\n5. **자신의 리스크 감수 능력**: 주식 투자는 항상 리스크가 따릅니다. 따라서 본인의 투자 성향을 고려하여 결정하는 것이 중요합니다.\n\n결정하기 전에 이러한 요소들을 종합적으로 분석해보시고, 필요하다면 전문가의 도움을 받는 것도 좋은 방법입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 296, 'prompt_tokens': 43, 'total_tokens': 339, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a5086b7b9a', 'id': 'chatcmpl-DSDRbuBSnG7uNrHIxteiUGIjEXrNV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b08-cd47-7f11-8cc8-26d05c1b187b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 296, 'total_tokens': 339, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
# 후속 질문 (이전 맥락 유지)
messages.append(HumanMessage(content="그렇다면 목표 주가는 얼마로 보시나요?"))

# %%
print(len(messages))
# Out:
# 4

# %%
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식을 매수할지 고민할 때 고려해야 할 몇 가지 요소가 있습니다.\n\n1. **재무상태**: 삼성전자의 최근 재무제표를 분석해 보세요. 매출, 순이익, 부채비율 등의 지표가 양호한지 확인하는 것이 중요합니다.\n\n2. **시장 전망**: 반도체와 전자기기 산업의 현재 시장 동향과 전망을 살펴보세요. 특히, 반도체 공급망, 경쟁사와의 비교, 글로벌 경제 상황 등이 중요한 요소입니다.\n\n3. **주가 추세**: 최근 주가의 변동성과 기술적 분석을 통해 매수를 고려할 시점을 판단할 수 있습니다. 최근 주가가 하락세라면 매수 기회로 볼 수도 있지만, 하락 이유를 분석하는 것이 필요합니다.\n\n4. **장기적인 투자 전략**: 삼성전자가 장기적으로 안정성 있는 기업이라는 점을 고려할 때, 장기 투자 목표에 부합한다면 매수하는 것이 좋을 수 있습니다.\n\n5. **자신의 리스크 감수 능력**: 주식 투자는 항상 리스크가 따릅니다. 따라서 본인의 투자 성향을 고려하여 결정하는 것이 중요합니다.\n\n결정하기 전에 이러한 요소들을 종합적으로 분석해보시고, 필요하다면 전문가의 도움을 받는 것도 좋은 방법입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 296, 'prompt_tokens': 43, 'total_tokens': 339, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a5086b7b9a', 'id': 'chatcmpl-DSDRbuBSnG7uNrHIxteiUGIjEXrNV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b08-cd47-7f11-8cc8-26d05c1b187b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 296, 'total_tokens': 339, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='그렇다면 목표 주가는 얼마로 보시나요?', additional_kwargs={}, response_metadata={})]

# %%
response = llm.invoke(messages)
response
# Out:
# AIMessage(content='삼성전자의 목표 주가는 다양한 요소에 의해 결정되므로, 정확한 수치를 제시하기는 어렵지만, 다음과 같은 기준을 활용해 보실 수 있습니다.\n\n1. **기업 실적**: 삼성전자의 최근 분기 실적과 연간 전망을 고려하여 EPS(주당순이익)를 기반으로 목표 주가를 계산할 수 있습니다.\n\n2. **P/E 비율**: 유사한 기업들의 주가 수익비율(P/E)을 참고하여 삼성전자의 적정 P/E 비율을 적용해 목표 주가를 산출할 수 있습니다. 예를 들어, 최근 EPS와 평균 P/E를 곱하여 목표 주가를 구할 수 있습니다.\n\n3. **산업 동향**: 반도체와 전자기기 시장의 변화와 경쟁사들의 성과도 목표 주가에 영향을 미칠 수 있습니다. 특히, 기술 혁신이나 생산 비용 절감 등과 같은 요소가 중요합니다.\n\n4. **뉴스와 이벤트**: 보도자료나 경제 지표, 정책 변화 등의 외부 요인을 살펴보는 것도 중요합니다. 이러한 요소는 주가의 단기 변동성에 큰 영향을 미칠 수 있습니다.\n\n5. **전문가 의견**: 다양한 증권사의 리서치 보고서를 참고하여 전문가들의 목표 주가를 비교하는 것도 유용합니다.\n\n결국 목표 주가는 시장 상황 및 기업의 성과에 따라 변동성이 크기 때문에, 주기적으로 업데이트하고 다양한 관점을 고려하는 것이 중요합니다. 필요하다면, 특정 수치를 제시하는 전문가의 시장 리서치를 참고하시길 권장드립니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 347, 'prompt_tokens': 359, 'total_tokens': 706, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_91c8a2e5b1', 'id': 'chatcmpl-DSDUvPdzhB9EGKiyJlGxWgXC1WFWK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0b-f08e-7542-9adc-e0c8f05b68f1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 359, 'output_tokens': 347, 'total_tokens': 706, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
messages.append(response)
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식을 매수할지 고민할 때 고려해야 할 몇 가지 요소가 있습니다.\n\n1. **재무상태**: 삼성전자의 최근 재무제표를 분석해 보세요. 매출, 순이익, 부채비율 등의 지표가 양호한지 확인하는 것이 중요합니다.\n\n2. **시장 전망**: 반도체와 전자기기 산업의 현재 시장 동향과 전망을 살펴보세요. 특히, 반도체 공급망, 경쟁사와의 비교, 글로벌 경제 상황 등이 중요한 요소입니다.\n\n3. **주가 추세**: 최근 주가의 변동성과 기술적 분석을 통해 매수를 고려할 시점을 판단할 수 있습니다. 최근 주가가 하락세라면 매수 기회로 볼 수도 있지만, 하락 이유를 분석하는 것이 필요합니다.\n\n4. **장기적인 투자 전략**: 삼성전자가 장기적으로 안정성 있는 기업이라는 점을 고려할 때, 장기 투자 목표에 부합한다면 매수하는 것이 좋을 수 있습니다.\n\n5. **자신의 리스크 감수 능력**: 주식 투자는 항상 리스크가 따릅니다. 따라서 본인의 투자 성향을 고려하여 결정하는 것이 중요합니다.\n\n결정하기 전에 이러한 요소들을 종합적으로 분석해보시고, 필요하다면 전문가의 도움을 받는 것도 좋은 방법입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 296, 'prompt_tokens': 43, 'total_tokens': 339, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a5086b7b9a', 'id': 'chatcmpl-DSDRbuBSnG7uNrHIxteiUGIjEXrNV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b08-cd47-7f11-8cc8-26d05c1b187b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 296, 'total_tokens': 339, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='그렇다면 목표 주가는 얼마로 보시나요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자의 목표 주가는 다양한 요소에 의해 결정되므로, 정확한 수치를 제시하기는 어렵지만, 다음과 같은 기준을 활용해 보실 수 있습니다.\n\n1. **기업 실적**: 삼성전자의 최근 분기 실적과 연간 전망을 고려하여 EPS(주당순이익)를 기반으로 목표 주가를 계산할 수 있습니다.\n\n2. **P/E 비율**: 유사한 기업들의 주가 수익비율(P/E)을 참고하여 삼성전자의 적정 P/E 비율을 적용해 목표 주가를 산출할 수 있습니다. 예를 들어, 최근 EPS와 평균 P/E를 곱하여 목표 주가를 구할 수 있습니다.\n\n3. **산업 동향**: 반도체와 전자기기 시장의 변화와 경쟁사들의 성과도 목표 주가에 영향을 미칠 수 있습니다. 특히, 기술 혁신이나 생산 비용 절감 등과 같은 요소가 중요합니다.\n\n4. **뉴스와 이벤트**: 보도자료나 경제 지표, 정책 변화 등의 외부 요인을 살펴보는 것도 중요합니다. 이러한 요소는 주가의 단기 변동성에 큰 영향을 미칠 수 있습니다.\n\n5. **전문가 의견**: 다양한 증권사의 리서치 보고서를 참고하여 전문가들의 목표 주가를 비교하는 것도 유용합니다.\n\n결국 목표 주가는 시장 상황 및 기업의 성과에 따라 변동성이 크기 때문에, 주기적으로 업데이트하고 다양한 관점을 고려하는 것이 중요합니다. 필요하다면, 특정 수치를 제시하는 전문가의 시장 리서치를 참고하시길 권장드립니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 347, 'prompt_tokens': 359, 'total_tokens': 706, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_91c8a2e5b1', 'id': 'chatcmpl-DSDUvPdzhB9EGKiyJlGxWgXC1WFWK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0b-f08e-7542-9adc-e0c8f05b68f1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 359, 'output_tokens': 347, 'total_tokens': 706, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
travel_messages = [
  SystemMessage(content= "당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다."),
  HumanMessage(content="부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.")
]

# %%
response = llm.invoke(travel_messages)
travel_messages.append(response)
travel_messages
# Out:
# [SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 **해운대 해수욕장**을 추천합니다. 해운대는 부산의 대표적인 해변으로, 아름다운 바다와 부드러운 모래사장, 다양한 해양 레포츠와 주변의 맛집, 카페, 문화 시설이 잘 어우러져 있어 많은 관광객들에게 사랑받고 있습니다.\n\n여름철에는 해수욕을 즐길 수 있고, 겨울철에는 바다의 경치를 감상하며 산책하기에도 좋습니다. 또한, 해운대 인근에는 동백섬과 누리마루 APEC 하우스와 같은 명소도 있어 한곳에서 여러 가지를 경험할 수 있는 장점이 있습니다. 부산의 아름다움을 느끼고, 여유로운 시간을 갖기에 최적의 장소입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 181, 'prompt_tokens': 49, 'total_tokens': 230, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_48d918fb56', 'id': 'chatcmpl-DSDqjodblfeDbyJhJQOkTslfXoKFw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b20-9298-7e82-8d5a-0e2bae997a2d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 181, 'total_tokens': 230, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
travel_messages.append(HumanMessage(content="부산역에서 그곳에 가는 교통편을 알려주세요."))
response2 = llm.invoke(travel_messages)
travel_messages.append(response2)  # ← AI 응답 먼저 추가

# %%
travel_messages.append(HumanMessage(content="그 근처에 먹을 만한 음식점들을 추천해주세요"))
response3 = llm.invoke(travel_messages)
travel_messages.append(response3)

# %%
travel_messages
# Out:
# [SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 **해운대 해수욕장**을 추천합니다. 해운대는 부산의 대표적인 해변으로, 아름다운 바다와 부드러운 모래사장, 다양한 해양 레포츠와 주변의 맛집, 카페, 문화 시설이 잘 어우러져 있어 많은 관광객들에게 사랑받고 있습니다.\n\n여름철에는 해수욕을 즐길 수 있고, 겨울철에는 바다의 경치를 감상하며 산책하기에도 좋습니다. 또한, 해운대 인근에는 동백섬과 누리마루 APEC 하우스와 같은 명소도 있어 한곳에서 여러 가지를 경험할 수 있는 장점이 있습니다. 부산의 아름다움을 느끼고, 여유로운 시간을 갖기에 최적의 장소입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 181, 'prompt_tokens': 49, 'total_tokens': 230, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_48d918fb56', 'id': 'chatcmpl-DSDqjodblfeDbyJhJQOkTslfXoKFw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b20-9298-7e82-8d5a-0e2bae997a2d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 181, 'total_tokens': 230, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='부산역에서 그곳에 가는 교통편을 알려주세요.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='부산역에서 해운대 해수욕장까지 가는 교통편은 여러 가지가 있습니다. 가장 일반적인 방법을 몇 가지 소개해 드릴게요.\n\n1. **지하철 이용하기**:\n   - **부산역**에서 **1호선 (남포방면)**에 탑승하여 **서면역**에서 하차합니다.\n   - 서면역에서 **2호선 (장산방면)**으로 환승한 후, 약 7정거장 이동하여 **해운대역**에서 하차합니다.\n   - 해운대역 5번 출구로 나와서 도보로 약 10분 정도 가면 해운대 해수욕장에 도착합니다.\n\n2. **버스 이용하기**:\n   - 부산역 근처의 버스 정류장에서 **1001, 1003, 1004, 139, 181, 200, 203, 303** 등의 버스를 타고 해운대 방향으로 가는 버스를 이용합니다.\n   - 목적지는 "해운대" 또는 "해운대 해수욕장"이라고 명시된 정류장에서 하차하면 됩니다.\n\n3. **택시 이용하기**:\n   - 부산역에서 택시를 타고 해운대 해수욕장까지 직접 가는 방법도 있습니다. 소요시간은 약 30분 정도이며, 교통 상황에 따라 달라질 수 있습니다.\n\n이렇게 간편하게 해운대 해수욕장까지 갈 수 있으니, 여행 잘 즐기시길 바랍니다!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 337, 'prompt_tokens': 254, 'total_tokens': 591, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9a7f4bef40', 'id': 'chatcmpl-DSDqqWu9mTfic0uyVP0XTvHV2rt2I', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b20-ae9b-7371-b61f-8fc1a0b3347e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 254, 'output_tokens': 337, 'total_tokens': 591, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='그 근처에 먹을 만한 음식점들을 추천해주세요', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='해운대 해수욕장 근처에는 다양한 맛집이 있어 여러 가지 음식을 즐길 수 있습니다. 아래 몇 가지 추천 드릴게요.\n\n1. **동백섬 횟집**:\n   - 신선한 회를 즐길 수 있는 해산물 전문점입니다. 해운대 바다를 바라보며 맛있는 회를 맛볼 수 있어요.\n\n2. **마시마시**:\n   - 일본식 돼지고기 덮밥과 라멘을 전문으로 하는 곳으로, 부담 없이 맛있는 한 끼를 즐길 수 있습니다.\n\n3. **해운대 암소갈비**:\n   - 고기 애호가들에게 추천하는 곳으로, 품질 좋은 갈비와 함께 다양한 반찬을 제공합니다. 분위기 좋은 식사 공간에서 즐길 수 있습니다.\n\n4. **어장**:\n   - 이곳은 바다의 신선한 해산물과 매운탕, 해물찜 등을 전문으로 하고 있으며, 저렴한 가격에 푸짐한 해산물 요리를 맛볼 수 있습니다.\n\n5. **올리브참치**:\n   - 건강한 참치 덮밥을 제공합니다. 깔끔하고 아늑한 분위기에서 참치 요리를 즐기고 싶다면 추천드립니다.\n\n6. **서면 비빔당**:\n   - 부산 특유의 비빔밥을 즐길 수 있는 곳으로, 신선한 재료로 만든 비빔밥이 인기입니다.\n\n위의 음식점들은 해운대 근처에 위치해 있어 해변을 즐긴 후 맛있는 식사를 하기에 좋습니다. 각 식당의 영업시간과 메뉴는 사전에 확인해 보시는 것이 좋습니다. 맛있는 식사 즐기세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 380, 'prompt_tokens': 612, 'total_tokens': 992, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9a7f4bef40', 'id': 'chatcmpl-DSDrDkoYVOlMcVOhOhY3X7IXfo77k', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b21-0976-7483-ab0a-c832525d4111-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 612, 'output_tokens': 380, 'total_tokens': 992, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
from langchain_community.callbacks import get_openai_callback

with get_openai_callback() as callback:
    response = llm.invoke(travel_messages)
    print(response.content)
    print(f"\n총 토큰: {callback.total_tokens}")
    print(f"프롬프트 토큰: {callback.prompt_tokens}")
    print(f"응답 토큰: {callback.completion_tokens}")
    print(f"비용(USD): ${callback.total_cost:.6f}")
# Out:
# 해운대 해수욕장 근처에는 다양한 맛집이 있어 여러 가지 음식을 즐길 수 있습니다. 아래 몇 가지 추천 드릴게요.
#
# 1. **동백섬 횟집**:
#    - 신선한 회를 즐길 수 있는 해산물 전문점입니다. 해운대 바다를 바라보며 맛있는 회를 맛볼 수 있어요.
#
# 2. **마시마시**:
#    - 일본식 돼지고기 덮밥과 라멘을 전문으로 하는 곳으로, 부담 없이 맛있는 한 끼를 즐길 수 있습니다.
#
# 3. **해운대 암소갈비**:
#    - 고기 애호가들에게 추천하는 곳으로, 품질 좋은 갈비와 함께 다양한 반찬을 제공합니다. 분위기 좋은 식사 공간에서 즐길 수 있습니다.
#
# 4. **어장**:
#    - 이곳은 바다의 신선한 해산물과 매운탕, 해물찜 등을 전문으로 하고 있으며, 저렴한 가격에 푸짐한 해산물 요리를 맛볼 수 있습니다.
#
# 5. **올리브참치**:
#    - 건강한 참치 덮밥을 제공합니다. 깔끔하고 아늑한 분위기에서 참치 요리를 즐기고 싶다면 추천드립니다.
#
# 6. **서면 비빔당**:
#    - 부산 특유의 비빔밥을 즐길 수 있는 곳으로, 신선한 재료로 만든 비빔밥이 인기입니다.
#
# 위의 음식점들은 해운대 근처에 위치해 있어 해변을 즐긴 후 맛있는 식사를 하기에 좋습니다. 각 식당의 영업시간과 메뉴는 사전에 확인해 보시는 것이 좋습니다. 맛있는 식사 즐기세요!
#
# 총 토큰: 1376
# 프롬프트 토큰: 996
# 응답 토큰: 380
# 비용(USD): $0.000377

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

llm = ChatOpenAI(model="gpt-4o-mini")

prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 주식 투자 전문가입니다."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}")
])

chain = prompt | llm

# %%
# 세션별 히스토리 저장소
store = {}

def get_session_history(session_id: str):
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

chain_with_history = RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="history"
)

# %%
# 첫 번째 질문(runnable chain)
response = chain_with_history.invoke(
    {"input": "삼성전자 주식을 지금 매수해도 될까요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자 주식을 지금 매수할 지에 대한 결정은 여러 요소에 따라 다르며, 개인의 투자 목표와 리스크 수용 능력에 의존합니다. 다음과 같은 사항들을 고려해 보시기 바랍니다:
#
# 1. **기업 실적**: 삼성전자의 최근 분기 실적과 연간 보고서를 확인해 보세요. 매출, 이익률, 영업이익 등의 주요 지표가 건강한지 살펴보는 것이 중요합니다.
#
# 2. **산업 동향**: 반도체 산업 및 스마트폰 시장의 현재 상황을 고려하세요. 글로벌 경제 여건, 산업 내 경쟁 상황 등이 삼성전자의 실적에 큰 영향을 미칠 수 있습니다.
#
# 3. **주가 추세**: 주식의 기술적 분석, 즉 차트 및 지표를 통해 현재 주가가 과거보다 어느 정도인지, 과매수 또는 과매도 상태인지 판단해 보세요.
#
# 4. **시장 전망**: 시장에 대한 전문가의 의견과 예상되는 변화에 대해 조사해 보세요. 애널리스트의 목표 주가 및 추천 의견도 참고할 수 있습니다.
#
# 5. **개인 투자 전략**: 당신의 투자 목표, 투자 시간, 리스크 수용 능력 등을 고려해 결정하세요. 장기적인 투자라면 단기 변동성에 흔들리지 않는 것이 중요합니다.
#
# 이 모든 정보를 바탕으로 신중하게 결정을 내리시기를 권장합니다. 주식 투자에는 항상 리스크가 있으므로, 개인의 상황에 맞는 최선의 전략을 수립하는 것이 중요합니다.

# %%
# 후속 질문 - 같은 session_id로 맥락 유지
response = chain_with_history.invoke(
    {"input": "그렇다면 목표 주가는 얼마로 보시나요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자의 목표 주가는 여러 요소에 따라 달라질 수 있으며, 전문가나 애널리스트마다 다르게 설정될 수 있습니다. 목표 주가는 기업의 실적, 산업 동향, 시장 상황, 기술적 분석 등 다양한 요소를 종합적으로 고려하여 책정됩니다.
#
# 직접적인 목표 주가는 제공할 수 없지만, 다음과 같은 요소를 통해 여러분 스스로 목표 주가를 설정하는 데 도움을 드릴 수 있습니다:
#
# 1. **실적 전망**: 삼성전자의 매출 성장률, 이익률, 그리고 향후 몇 분기간의 성장 전망을 반영해 목표 주가를 설정해 보세요.
#
# 2. **P/E 비율**: 주가 수익 비율(PER)과 같은 재무 비율을 고려하여, 업계 평균과 비교해 보세요. 이 비율을 바탕으로 현재 주가에서 EPS(주당 순이익)를 곱하여 목표 주가를 예상해 볼 수 있습니다.
#
# 3. **기술적 분석**: 차트를 분석하여 저항선과 지지선을 찾아보세요. 기술적 분석에서 제시하는 가격 목표도 유용할 수 있습니다.
#
# 4. **경쟁사와 비교**: 삼성전자의 주요 경쟁사와의 비교를 통해 시장 내 위치를 평가하면 목표 주가 설정에 도움이 될 수 있습니다.
#
# 최종적으로, 여러분의 투자 목표와 리스크 수용 범위를 고려해 목표 주가를 설정하는 것이 중요합니다. 필요하다면 금융 전문가와 상담하는 것도 좋은 방법입니다.

# %%
# 후속 질문 - 같은 session_id로 맥락 유지
response = chain_with_history.invoke(
    {"input": "그렇다면, 주가의 위험요소는 무엇인가요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자와 같은 대형 기업의 주가는 여러 위험 요소에 영향을 받을 수 있습니다. 주요 위험 요소는 다음과 같습니다:
#
# 1. **전반적인 경제 상황**: 글로벌 경제 둔화, 금리 인상, 인플레이션 등 macroeconomic 요소는 주가에 큰 영향을 미칠 수 있습니다. 이러한 경제적 요인은 소비자 수요 및 기업 수익에 직접적으로 연결됩니다.
#
# 2. **경쟁 심화**: 반도체 및 전자기기 시장에서의 경쟁이 심화될 경우, 삼성전자의 시장 점유율이나 가격 결정력에 부정적인 영향을 미칠 수 있습니다.
#
# 3. **기술 변화**: 기술 발전의 속도는 매우 빠르므로, 새로운 기술이나 제품이 시장에 등장할 경우 기존 제품이 빠르게 구식이 될 수 있습니다. 이를 따라잡지 못하면 매출에 타격을 받을 수 있습니다.
#
# 4. **정치적 리스크**: 지역적 또는 글로벌 정치적 불안정성, 무역 전쟁, 제재 등이 기업의 운영에 영향을 줄 수 있습니다. 예를 들어, 한일 관계나 중국과의 무역 문제는 삼성전자에도 영향을 미칠 수 있습니다.
#
# 5. **환율 변동**: 삼성전자는 다국적 기업이기 때문에 환율 변동도 중요한 요소입니다. 원화 대비 다른 국가 통화의 환율 변동은 해외 매출 및 수익성에 영향을 미칠 수 있습니다.
#
# 6. **원자재 가격 변동**: 반도체 생산에 필요한 원자재 가격 상승은 생산 비용에 부담을 줄 수 있습니다. 물가 상승이나 공급망 문제도 고려해야 합니다.
#
# 7. **법적 및 규제 리스크**: 기업 활동에 영향을 줄 수 있는 새로운 법률이나 규제의 출현도 위험 요소입니다. 특히 반독점법이나 환경 규제 등에 대한 법적 대응이 필요할 수 있습니다.
#
# 이와 같은 위험 요소를 고려하여, 기업의 현재 상황을 분석하고 장기적인 투자 전략을 수립하는 것이 중요합니다.

# %%
total_tokens_list= []

with get_openai_callback() as cb:
    response = llm.invoke(travel_messages)
    travel_messages.append(response)
    for message in travel_messages:
      print(type(message), message)
      total_tokens_list.append(cb.total_tokens)
      print(f'token 사용량: {cb.total_tokens}')
# Out:
# <class 'langchain_core.messages.system.SystemMessage'> content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.' additional_kwargs={} response_metadata={}
# token 사용량: 1376
# <class 'langchain_core.messages.human.HumanMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.' additional_kwargs={} response_metadata={}
# token 사용량: 1376
# <class 'langchain_core.messages.ai.AIMessage'> content='부산 여행에서 딱 한 곳만을 가봐야 한다면 **해운대 해수욕장**을 추천합니다. 해운대는 부산의 대표적인 해변으로, 아름다운 바다와 부드러운 모래사장, 다양한 해양 레포츠와 주변의 맛집, 카페, 문화 시설이 잘 어우러져 있어 많은 관광객들에게 사랑받고 있습니다.\n\n여름철에는 해수욕을 즐길 수 있고, 겨울철에는 바다의 경치를 감상하며 산책하기에도 좋습니다. 또한, 해운대 인근에는 동백섬과 누리마루 APEC 하우스와 같은 명소도 있어 한곳에서 여러 가지를 경험할 수 있는 장점이 있습니다. 부산의 아름다움을 느끼고, 여유로운 시간을 갖기에 최적의 장소입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 181, 'prompt_tokens': 49, 'total_tokens': 230, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_48d918fb56', 'id': 'chatcmpl-DSDqjodblfeDbyJhJQOkTslfXoKFw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b20-9298-7e82-8d5a-0e2bae997a2d-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 49, 'output_tokens': 181, 'total_tokens': 230, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# token 사용량: 1376
# <class 'langchain_core.messages.human.HumanMessage'> content='부산역에서 그곳에 가는 교통편을 알려주세요.' additional_kwargs={} response_metadata={}
# token 사용량: 1376
# <class 'langchain_core.messages.ai.AIMessage'> content='부산역에서 해운대 해수욕장까지 가는 교통편은 여러 가지가 있습니다. 가장 일반적인 방법을 몇 가지 소개해 드릴게요.\n\n1. **지하철 이용하기**:\n   - **부산역**에서 **1호선 (남포방면)**에 탑승하여 **서면역**에서 하차합니다.\n   - 서면역에서 **2호선 (장산방면)**으로 환승한 후, 약 7정거장 이동하여 **해운대역**에서 하차합니다.\n   - 해운대역 5번 출구로 나와서 도보로 약 10분 정도 가면 해운대 해수욕장에 도착합니다.\n\n2. **버스 이용하기**:\n   - 부산역 근처의 버스 정류장에서 **1001, 1003, 1004, 139, 181, 200, 203, 303** 등의 버스를 타고 해운대 방향으로 가는 버스를 이용합니다.\n   - 목적지는 "해운대" 또는 "해운대 해수욕장"이라고 명시된 정류장에서 하차하면 됩니다.\n\n3. **택시 이용하기**:\n   - 부산역에서 택시를 타고 해운대 해수욕장까지 직접 가는 방법도 있습니다. 소요시간은 약 30분 정도이며, 교통 상황에 따라 달라질 수 있습니다.\n\n이렇게 간편하게 해운대 해수욕장까지 갈 수 있으니, 여행 잘 즐기시길 바랍니다!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 337, 'prompt_tokens': 254, 'total_tokens': 591, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9a7f4bef40', 'id': 'chatcmpl-DSDqqWu9mTfic0uyVP0XTvHV2rt2I', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b20-ae9b-7371-b61f-8fc1a0b3347e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 254, 'output_tokens': 337, 'total_tokens': 591, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# token 사용량: 1376
# <class 'langchain_core.messages.human.HumanMessage'> content='그 근처에 먹을 만한 음식점들을 추천해주세요' additional_kwargs={} response_metadata={}
# token 사용량: 1376
# <class 'langchain_core.messages.ai.AIMessage'> content='해운대 해수욕장 근처에는 다양한 맛집이 있어 여러 가지 음식을 즐길 수 있습니다. 아래 몇 가지 추천 드릴게요.\n\n1. **동백섬 횟집**:\n   - 신선한 회를 즐길 수 있는 해산물 전문점입니다. 해운대 바다를 바라보며 맛있는 회를 맛볼 수 있어요.\n\n2. **마시마시**:\n   - 일본식 돼지고기 덮밥과 라멘을 전문으로 하는 곳으로, 부담 없이 맛있는 한 끼를 즐길 수 있습니다.\n\n3. **해운대 암소갈비**:\n   - 고기 애호가들에게 추천하는 곳으로, 품질 좋은 갈비와 함께 다양한 반찬을 제공합니다. 분위기 좋은 식사 공간에서 즐길 수 있습니다.\n\n4. **어장**:\n   - 이곳은 바다의 신선한 해산물과 매운탕, 해물찜 등을 전문으로 하고 있으며, 저렴한 가격에 푸짐한 해산물 요리를 맛볼 수 있습니다.\n\n5. **올리브참치**:\n   - 건강한 참치 덮밥을 제공합니다. 깔끔하고 아늑한 분위기에서 참치 요리를 즐기고 싶다면 추천드립니다.\n\n6. **서면 비빔당**:\n   - 부산 특유의 비빔밥을 즐길 수 있는 곳으로, 신선한 재료로 만든 비빔밥이 인기입니다.\n\n위의 음식점들은 해운대 근처에 위치해 있어 해변을 즐긴 후 맛있는 식사를 하기에 좋습니다. 각 식당의 영업시간과 메뉴는 사전에 확인해 보시는 것이 좋습니다. 맛있는 식사 즐기세요!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 380, 'prompt_tokens': 612, 'total_tokens': 992, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9a7f4bef40', 'id': 'chatcmpl-DSDrDkoYVOlMcVOhOhY3X7IXfo77k', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b21-0976-7483-ab0a-c832525d4111-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 612, 'output_tokens': 380, 'total_tokens': 992, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# token 사용량: 1376
# <class 'langchain_core.messages.ai.AIMessage'> content='해운대 해수욕장 근처에는 다양한 맛집이 있어 여러 가지 음식을 즐길 수 있습니다. 아래 몇 가지 추천 드릴게요.\n\n1. **동백섬 횟집**:\n   - 신선한 회를 즐길 수 있는 해산물 전문점입니다. 해운대 바다를 바라보며 맛있는 회를 맛볼 수 있어요.\n\n2. **마시마시**:\n   - 일본식 돼지고기 덮밥과 라멘을 전문으로 하는 곳으로, 부담 없이 맛있는 한 끼를 즐길 수 있습니다.\n\n3. **해운대 암소갈비**:\n   - 고기 애호가들에게 추천하는 곳으로, 품질 좋은 갈비와 함께 다양한 반찬을 제공합니다. 분위기 좋은 식사 공간에서 즐길 수 있습니다.\n\n4. **어장**:\n   - 이곳은 바다의 신선한 해산물과 매운탕, 해물찜 등을 전문으로 하고 있으며, 저렴한 가격에 푸짐한 해산물 요리를 맛볼 수 있습니다.\n\n5. **올리브참치**:\n   - 건강한 참치 덮밥을 제공합니다. 깔끔하고 아늑한 분위기에서 참치 요리를 즐기고 싶다면 추천드립니다.\n\n6. **서면 비빔당**:\n   - 부산 특유의 비빔밥을 즐길 수 있는 곳으로, 신선한 재료로 만든 비빔밥이 인기입니다.\n\n위의 음식점들은 해운대 근처에 위치해 있어 해변을 즐긴 후 맛있는 식사를 하기에 좋습니다. 각 식당의 영업시간과 메뉴는 사전에 확인해 보시는 것이 좋습니다. 맛있는 식사 즐기세요!' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 380, 'prompt_tokens': 996, 'total_tokens': 1376, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_9a7f4bef40', 'id': 'chatcmpl-DSE5M7Pa7il3aeUt1aHFr5lPuAPrs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d6b2e-6884-7c23-a3de-d162c741fbc6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 996, 'output_tokens': 380, 'total_tokens': 1376, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# token 사용량: 1376
