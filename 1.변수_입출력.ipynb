# %% [markdown]
# # 시작

# %%
3000*7
# Out:
# 21000

# %%
print("hello python")
print (32)
print ('계산 :', 3000*2, '입니다')
# Out:
# hello python
# 32
# 계산 : 6000 입니다

# %%
sale = 10*2000
print("오늘 매출은 ", sale, "입니다")
# Out:
# 오늘 매출은  20000 입니다

# %%
#성장율 = (이번달 매출 - 지난달 매출) / 지난달 매출 * 100
성장율 = (2000-1000)/1000 * 100
print ("이번달의 성장률은" , 성장율,"% 입니다")
# Out:
# 이번달의 성장률은 100.0 % 입니다

# %%
이달매출 = 500
지난달매출 = 2500
성장율 = (이달매출-지난달매출)/지난달매출*100
print ("이번달의 성장율은" , 성장율,"% 입니다")
# Out:
# 이번달의 성장율은 -80.0 % 입니다

# %%
이달매출 = input('이번달 매출액을 입력하세요')
지난달매출 = input ('지난달 매출액을 입력하세요')
print(이달매출,지난달매출)
# Out:
# 이번달 매출액을 입력하세요 1000
# 지난달 매출액을 입력하세요 2000
# 1000 2000

# %%
#당신의 이름을 알려주세요
#이름님! 반갑습니다!
이름 = input ('당신의 이름을 알려주세요')
print (이름+ '님!', '반갑습니다!')
# Out:
# 당신의 이름을 알려주세요 허유나
# 허유나님! 반갑습니다!

# %% [markdown]
# # Print()의 활용

# %%
가격 = 1000
수량 =10
매출 = 가격 * 수량 
print(매출)
# Out:
# 10000

# %%
print("이번달 매출은", 매출, "입니다.", sep= " ")
# Out:
# 이번달 매출은 10000 입니다.

# %%
#apple, banana, cherry
과일목록1 = 'apple'
과일목록2 = 'banana'
과일목록3 = 'cherry'
print(과일목록1, 과일목록2, 과일목록3, sep=', ')
# Out:
# apple, banana, cherry

# %%
print(과일목록1, 과일목록2, 과일목록3, sep='\n') #sep= ', '
# Out:
# apple
# banana
# cherry

# %%
12345, '12345'
# Out:
# (12345, '12345')

# %%
type(12345), type('12345')
# Out:
# (int, str)

# %%
data = 12345
data2 = '12345'
type(data), type(data2)
# Out:
# (int, str)

# %%
12345+10, '12345'+'10'
# Out:
# (12355, '1234510')

# %%
data+10, data2+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data+10, data2+10
#
# TypeError: can only concatenate str (not "int") to str

# %%
name = 'yoona'
age = 20
#stringformat
print('나의 이름은 {}이고, 나이는 {}입니다.'.format(name, age))
# Out:
# 나의 이름은 yoona이고, 나이는 20입니다.

# %%
#fstring
print(f"나의 이름은 {name}이고, 나이는 {age}입니다.")
# Out:
# 나의 이름은 yoona이고, 나이는 20입니다.

# %%
#fstring
print(f"입력한 이름: {name}")
print(f"내년 나이: {age+1}")
# Out:
# 입력한 이름: yoona
# 내년 나이: 21

# %%
int('10')
# Out:
# 10

# %%
int(age)+1
# Out:
# 21

# %%
type(int(age)+1)
# Out:
# int

# %%
age=20.8
type(age)
# Out:
# float

# %%
student_name = 'yoona'
name_1 = 'yoona'

# %%
1_name = 'yoona'
# Out:
#   Cell In[34], line 1
#     1_name = 'yoona'
#      ^
# SyntaxError: invalid decimal literal

# %%
x =10
a =20

# %%
PI = 3.141592 #constant 상수

# %%
MAX_VALUE = 1000
MIN_VALUE = 0

# %%
input() #shift+tab
print(
# Out:
#   Cell In[36], line 2
#     print(
#           ^
# SyntaxError: incomplete input

# %%
a = 30,20,10 #패킹
type(a), a
# Out:
# (tuple, (30, 20, 10))

# %%
x,y,z = a #언패킹
x,y,z
# Out:
# (30, 20, 10)

# %%
b=30,
type(b)
# Out:
# tuple

# %%
x,y,y1= a #언패킹
x,y
# Out:
# (30, 20)

# %%
a = 10
b = a
a,b
# Out:
# (10, 10)

# %%
id(a), id(b)
# Out:
# (140712419355352, 140712419355352)

# %%
a = 10
id(a)
# Out:
# 140712419355352

# %%
user_name = 'yoona' #snake
userName = 'yoona' #carmel
username = 'yoona'
_name = 'yoona' #private
__name __ = 'yoona' #double underscore 던더

# %%
a = "hi"
b = "Hi"
id(a), id(b)
# Out:
# (140712419398112, 2027325268224)

# %%
a = 'Hi'
id(a), id(b)
# Out:
# (2027325268224, 2027325268224)

# %%
#변수의 영역 namespace
지역변수, 전역변수

# %%
def local_exam (): #사용자정의함수
    local_var = 100
    print(f"함수내부: {local_var}")

local_exam()
local_var = 200
local_exam()
print(f"함수외부: {local_var}")
# Out:
# 함수내부: 100
# 함수내부: 100
# 함수외부: 200

# %%
counter = 0
def inc_counter():
    global counter
    counter = counter + 1
    print(counter)
    
inc_counter()
inc_counter()
inc_counter()
# Out:
# 1
# 2
# 3
