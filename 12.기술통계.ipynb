# %% [markdown]
# # 중심 경향성

# %% [markdown]
# ## 평균

# %%
import numpy as np
data = [10,20,30,40,50,60]
sum(data)/len(data)
np.mean(data)
# Out:
# np.float64(35.0)

# %%
#(5000*8 + 9000*2) / (8+2)
prices= [5000,9000]
counts = [8,2]
weighted_mean = np.average(prices, weights = counts)
weighted_mean
# Out:
# np.float64(5800.0)

# %%
#가중평균 조종사들의 평균점수 구하기
data = {
    '점수' : [97,94,92,91,90,89,78,60],
    '인원수' : [4,11,12,21,30,12,9,1] #총 100명 
}
#넘파이로 바로 가중평균 구하기
# import numpy as np 이미 위에서 했음
weighted_mean = np.average(data['점수'], weights=data['인원수'])
weighted_mean
# Out:
# np.float64(89.67)

# %%
total_people = sum(datat['인원수'])

print('#전체평가대상자 수 {total_people}')
print('#평균점수 {total_people}')
print(f'#기준미달 {weighted_score}')
risk_score = weighted_score

print(f'#기준미달 {risk_score}'인 조종사가 {}명입니다.')

# %%
# 초기 매출
initial = 100

# 시나리오 적용
step1 = initial * 2.0      # +100%
step2 = step1 * 0.5        # -50%
final = step2

print(f"초기: {initial}만원")
print(f"1차 후: {step1}만원")
print(f"최종: {final}만원")
print(f"\n실제 변화: {((final/initial - 1) * 100):.1f}%")
# Out:
# 초기: 100만원
# 1차 후: 200.0만원
# 최종: 100.0만원
#
# 실제 변화: 0.0%

# %%
# 산술평균
arithmetic = (100 + (-50)) / 2
print(f"산술평균: {arithmetic:.1f}%")

# 기하평균
geometric = (np.sqrt(2.0 * 0.5) - 1) * 100
print(f"기하평균: {geometric:.1f}%")
# Out:
# 산술평균: 25.0%
# 기하평균: 0.0%

# %%
# import numpy as np
from scipy import stats

# 1. 데이터: 갈 때 100km/h, 올 때 50km/h
speeds = [100, 50]

# 2. 평균 계산 비교
# A. 산술평균 (오답)
arithmetic = np.mean(speeds)

# B. 조화평균 (정답)
harmonic = stats.hmean(speeds)

# 3. 결과 리포트
print(f"데이터: {speeds}")
print("-" * 35)
print(f"1. [❌ 오류] 산술평균: {arithmetic:.2f} km/h")
print("-" * 35)
print(f"2. [✅ 정답] 조화평균: {harmonic:.2f} km/h")
print(f"   >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'")
print(f"   >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.")
# Out:
# 데이터: [100, 50]
# -----------------------------------
# 1. [❌ 오류] 산술평균: 75.00 km/h
# -----------------------------------
# 2. [✅ 정답] 조화평균: 66.67 km/h
#    >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'
#    >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.

# %% [markdown]
# # 중앙값

# %%
data = [10, 20, 30, 40, 50]
median_value = np.median(data)
print(median_value)
# Out:
# 30.0

# %%
scores = [65, 75, 80, 85, 95]

# 백분위수 계산
p25 = np.percentile(scores, 25)  # Q1
p50 = np.percentile(scores, 50)  # 중앙값
p75 = np.percentile(scores, 75)  # Q3

print(f"25번째 백분위수: {p25}")  # 75.0
print(f"50번째 백분위수(중앙값): {p50}")  # 80.0
print(f"75번째 백분위수: {p75}")  # 85.0
print(f"사분위간 범위(IQR): {p75 - p25}")  # 10.0
# Out:
# 25번째 백분위수: 75.0
# 50번째 백분위수(중앙값): 80.0
# 75번째 백분위수: 85.0
# 사분위간 범위(IQR): 10.0

# %% [markdown]
# # 최빈값

# %%
scores = [70, 80, 80, 90, 60, 80, 70]
counts = {}

for x in scores:
    if x in counts:
        counts[x] += 1
    else:
        counts[x] = 1

counts
# 결과
{70: 2, 80: 3, 90: 1, 60: 1}
#최빈값은 ? 80

#함수로 구하기
mode = max(counts, key=counts.get)
mode
# Out:
# 80

# %%
import pandas as pd
pd.Series(scores)
# Out:
# 0    70
# 1    80
# 2    80
# 3    90
# 4    60
# 5    80
# 6    70
# dtype: int64

# %%
#판다스로 최빈값 가져오기
import pandas as pd
score_data = pd.Series(scores)
# pd.DataFrame(scores)
score_data.mode()
# Out:
# 0    80
# dtype: int64

# %% [markdown]
# # 변동성 - 범위

# %%
data1 = [50, 50, 50, 50, 50]
data2 = [10, 30, 50, 70, 90]
data3 = [30, 40, 50, 60, 70]

np.mean(data1), np.mean(data2), np.mean(data3)
# Out:
# (np.float64(50.0), np.float64(50.0), np.float64(50.0))

# %%
data2_range = max(data2) - min(data2)
data3_range = max(data3) - min(data3)
data2_range, data3_rang
# Out:
# (80, 40)

# %% [markdown]
# # 변동성 - 분산

# %%
import numpy as np

data = [10, 20, 30, 40, 50]
variance_value = np.var(data)
print(variance_value)
# Out:
# 200.0

# %%
np.var(data2), np.var(data3)
# Out:
# (np.float64(800.0), np.float64(200.0))

# %%
np.std(data2), np.std(data3)
# Out:
# (np.float64(28.284271247461902), np.float64(14.142135623730951))

# %% [markdown]
# # 변동성 - 빈도분포도

# %%
data = [
    [47, 10, 31, 25, 20],
    [2, 11, 31, 25, 21],
    [44, 14, 15, 26, 21],
    [41, 14, 16, 26, 21],
    [7, 30, 17, 27, 24],
    [6, 30, 16, 29, 24],
    [35, 32, 15, 29, 23],
    [38, 33, 19, 28, 20],
    [35, 34, 18, 29, 21],
    [36, 32, 16, 27, 20],
]
data
# Out:
# [[47, 10, 31, 25, 20],
#  [2, 11, 31, 25, 21],
#  [44, 14, 15, 26, 21],
#  [41, 14, 16, 26, 21],
#  [7, 30, 17, 27, 24],
#  [6, 30, 16, 29, 24],
#  [35, 32, 15, 29, 23],
#  [38, 33, 19, 28, 20],
#  [35, 34, 18, 29, 21],
#  [36, 32, 16, 27, 20]]

# %%
df = pd.DataFrame(data, columns = ['A','B','C','D','E'])
df
# Out:
#     A   B   C   D   E
# 0  47  10  31  25  20
# 1   2  11  31  25  21
# 2  44  14  15  26  21
# 3  41  14  16  26  21
# 4   7  30  17  27  24
# 5   6  30  16  29  24
# 6  35  32  15  29  23
# 7  38  33  19  28  20
# 8  35  34  18  29  21
# 9  36  32  16  27  20

# %%
import matplotlib.pyplot as plt
plt.hist(df)
# Out:
# (array([[ 2.,  1.,  0.,  0.,  0.,  0.,  0.,  3.,  2.,  2.],
#         [ 0.,  1.,  3.,  0.,  0.,  0.,  5.,  1.,  0.,  0.],
#         [ 0.,  0.,  2.,  6.,  0.,  0.,  2.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0.,  7.,  3.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <a list of 5 BarContainer objects>)

# %%
plt.hist(df['A'])
# Out:
# (array([2., 1., 0., 0., 0., 0., 0., 3., 2., 2.]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['B'])
# Out:
# (array([2., 2., 0., 0., 0., 0., 0., 0., 2., 4.]),
#  array([10. , 12.4, 14.8, 17.2, 19.6, 22. , 24.4, 26.8, 29.2, 31.6, 34. ]),
#  <BarContainer object of 10 artists>)

# %%
for col in df:
    #print(col)
    plt.hist(df[col])
    plt.show()

# %% [markdown]
# ## 첨도
# - 양의 첨도 : 정규분포보다 값의 크기만큼 뾰족하다. 꼬리가 두껍다(길다)
# - 음의 첨도 : 정규분포보다 값의 크기만큼 눌려있다. 꼬리가 얇고 짧다. 평균주변에 고르게 있다.

# %%
from scipy.stats import kurtosis
positive_kurtosis = [
    50, 50, 50, 50, 50,
    48, 52,
    35, 65
]
negative_kurtosis = [
    42, 44, 46, 48,
    52, 54, 56, 58
]
pos_kurtosis_value = kurtosis(positive_kurtosis )
neg_kurtosis_value = kurtosis(negative_kurtosis )

print(pos_kurtosis_value, neg_kurtosis_value )
# Out:
# 1.345540702885148 -1.4266666666666667

# %%
plt.hist(positive_kurtosis)
# Out:
# (array([1., 0., 0., 0., 1., 6., 0., 0., 0., 1.]),
#  array([35., 38., 41., 44., 47., 50., 53., 56., 59., 62., 65.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(negative_kurtosis)
# Out:
# (array([1., 1., 1., 1., 0., 0., 1., 1., 1., 1.]),
#  array([42. , 43.6, 45.2, 46.8, 48.4, 50. , 51.6, 53.2, 54.8, 56.4, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
from scipy.stats import skew

data = [10, 20, 30, 40, 100]  # 오른쪽으로 치우친 데이터
skew_value = skew(data)
print(skew_value)  # 양수 (오른쪽 꼬리)
# Out:
# 1.1384199576606167

# %% [markdown]
# # 그래프로 표현하기

# %%
#막대도표 
import matplotlib.pyplot as plt #matplotlib안에 pyplot이라는 서브패키지가 있음

# %%
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
counts = [12, 25, 18, 8, 30]

plt.bar(teams, counts) #캔버스를 그리고 막대차트를 만듦 데이터를 넣어줘야함. 위에가 데이터!!
#x축 y출 순서대로 데이터 지정
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np

# %%
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
score_2025 = [12, 25, 18, 8, 30]
score_2024 = [10, 20, 15, 8, 35]

plt.bar(teams, score_2025, label ='2025')
plt.bar(teams, score_2024, label = '2024')#한장에 캔버스에 2025,2024 순서대로 쌓아짐
plt.legend()

# %%
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
score_2025 = [12, 25, 18, 8, 30]
score_2024 = [10, 20, 15, 8, 35]

x = np.arange(len(teams))
width = 0.35

plt.bar(x - width/2, score_2025, width, label ='2025')
plt.bar(x + width/2, score_2024, width, label = '2024')

#x축 인덱스 대신 teams의 이름으로 교체
plt.xticks(x, teams)
# plt.bar(teams, score_2025, label ='2025')
# plt.bar(teams, score_2024, label = '2024')#한장에 캔버스에 2025,2024 순서대로 쌓아짐
plt.legend()

# %%
#원도표/파이차트 
# 1. 데이터 준비 (시장 점유율 상황)
labels = ['Company A', 'Company B', 'Company C', 'Others']
sizes = [45, 30, 15, 10]  # 합이 100이 되게 하는 것이 일반적
plt.pie(sizes, labels=labels, autopct='%1.1f%%') 
#typeError pie() missing 1 required positional argument: 'x' argument가 하나는 있어야지.
# Out:
# ([<matplotlib.patches.Wedge at 0x24a16348550>,
#   <matplotlib.patches.Wedge at 0x24a16348490>,
#   <matplotlib.patches.Wedge at 0x24a16349360>,
#   <matplotlib.patches.Wedge at 0x24a16349b10>],
#  [Text(0.17207793356064993, 1.0864571711675968, 'Company A'),
#   Text(-0.8899184718302892, -0.6465640830538323, 'Company B'),
#   Text(0.4993897495105265, -0.9801070748055101, 'Company C'),
#   Text(1.0461621838648125, -0.339918644753721, 'Others')],
#  [Text(0.09386069103308177, 0.5926130024550527, '45.0%'),
#   Text(-0.485410075543794, -0.352671318029363, '30.0%'),
#   Text(0.2723944088239235, -0.5346038589848237, '15.0%'),
#   Text(0.5706339184717159, -0.185410169865666, '10.0%')])

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%', wedgeprops={'width' :0.8}) 
#함수의 속성은 comma해야됌 
# width 숫자가 커지면 안에 동그라미가 작아짐.
# Out:
# ([<matplotlib.patches.Wedge at 0x24a16af4760>,
#   <matplotlib.patches.Wedge at 0x24a16af46a0>,
#   <matplotlib.patches.Wedge at 0x24a16af5510>,
#   <matplotlib.patches.Wedge at 0x24a16af5cc0>],
#  [Text(0.17207793356064993, 1.0864571711675968, 'Company A'),
#   Text(-0.8899184718302892, -0.6465640830538323, 'Company B'),
#   Text(0.4993897495105265, -0.9801070748055101, 'Company C'),
#   Text(1.0461621838648125, -0.339918644753721, 'Others')],
#  [Text(0.09386069103308177, 0.5926130024550527, '45.0%'),
#   Text(-0.485410075543794, -0.352671318029363, '30.0%'),
#   Text(0.2723944088239235, -0.5346038589848237, '15.0%'),
#   Text(0.5706339184717159, -0.185410169865666, '10.0%')])

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\admin\miniconda3\envs\stats\lib\site-packages (1.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2.2.5)
# Requirement already satisfied: requests>=2.31 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (4.14.2)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (6.33.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)

# %%
import yfinance as yf

# %%
import yfinance as yf
ticker = '005930.KS'
yf.download(ticker,period = '1y')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price               Close           High            Low           Open  \
# Ticker          005930.KS      005930.KS      005930.KS      005930.KS
# Date
# 2025-01-13   53215.187500   54100.467884   53215.187500   53707.009935
# 2025-01-14   53018.457031   53707.008421   52821.728063   53313.550484
# 2025-01-15   52821.726562   53805.371377   52624.997600   53215.184488
# 2025-01-16   53411.914062   54100.465441   53215.185097   53313.549580
# 2025-01-17   52821.726562   53215.184488   52329.904155   52920.091044
# ...                   ...            ...            ...            ...
# 2026-01-06  138900.000000  139300.000000  132700.000000  135300.000000
# 2026-01-07  141000.000000  144400.000000  137600.000000  143500.000000
# 2026-01-08  138800.000000  144500.000000  138300.000000  138300.000000
# 2026-01-09  139000.000000  140700.000000  135200.000000  136000.000000
# 2026-01-12  140350.000000  142000.000000  139300.000000  141000.000000
#
# Price         Volume
# Ticker     005930.KS
# Date
# 2025-01-13  16868600
# 2025-01-14  17465926
# 2025-01-15  18625025
# 2025-01-16  18627298
# 2025-01-17  18805344
# ...              ...
# 2026-01-06  45321341
# 2026-01-07  46317413
# 2026-01-08  41449329
# 2026-01-09  29520566
# 2026-01-12   9944142
#
# [241 rows x 5 columns]

# %%
import yfinance as yf
ticker = '005930.KS'
data = yf.download(ticker, period = '1y')
type(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker         005930.KS     005930.KS     005930.KS     005930.KS 005930.KS
# Date
# 2025-01-13  53215.183594  54100.463912  53215.183594  53707.005993  16868600
# 2025-01-14  53018.453125  53707.004464  52821.724171  53313.546556  17465926
# 2025-01-15  52821.726562  53805.371377  52624.997600  53215.184488  18625025
# 2025-01-16  53411.910156  54100.461484  53215.181205  53313.545681  18627298
# 2025-01-17  52821.726562  53215.184488  52329.904155  52920.091044  18805344

# %%
data.tail() #볼드체는 인덱스임 알아서 인덱스를 정하는거임.
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker     005930.KS 005930.KS 005930.KS 005930.KS 005930.KS
# Date
# 2026-01-06  138900.0  139300.0  132700.0  135300.0  45321341
# 2026-01-07  141000.0  144400.0  137600.0  143500.0  46317413
# 2026-01-08  138800.0  144500.0  138300.0  138300.0  41449329
# 2026-01-09  139000.0  140700.0  135200.0  136000.0  29520566
# 2026-01-12  140400.0  142000.0  139300.0  141000.0   9973069

# %%
plt.figure(figsize= (12,5))
plt.plot(data.index, data['Close'])

# %%
data['Close'] #리스트일때 대괄호 and index
# Out:
# Ticker          005930.KS
# Date
# 2025-01-13   53215.183594
# 2025-01-14   53018.453125
# 2025-01-15   52821.726562
# 2025-01-16   53411.910156
# 2025-01-17   52821.726562
# ...                   ...
# 2026-01-06  138900.000000
# 2026-01-07  141000.000000
# 2026-01-08  138800.000000
# 2026-01-09  139000.000000
# 2026-01-12  140400.000000
#
# [241 rows x 1 columns]

# %%
# 히스토그램

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#랜덤한 1000개의 데이터 생성
data = np.random.normal(loc=50000, scale=150000, size=1000)
len(data)
# Out:
# 1000

# %%
plt.hist(data)
# Out:
# (array([ 10.,  45., 101., 176., 220., 227., 138.,  60.,  20.,   3.]),
#  array([-389417.30350034, -296829.17860639, -204241.05371243,
#         -111652.92881848,  -19064.80392452,   73523.32096943,
#          166111.44586339,  258699.57075734,  351287.6956513 ,
#          443875.82054525,  536463.94543921]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins=30)
# Out:
# (array([ 3.,  2.,  5.,  8., 18., 19., 22., 35., 44., 55., 65., 56., 74.,
#         82., 64., 88., 84., 55., 46., 46., 46., 21., 22., 17., 12.,  6.,
#          2.,  0.,  1.,  2.]),
#  array([-389417.30350034, -358554.59520236, -327691.88690437,
#         -296829.17860639, -265966.4703084 , -235103.76201042,
#         -204241.05371243, -173378.34541445, -142515.63711646,
#         -111652.92881848,  -80790.22052049,  -49927.51222251,
#          -19064.80392452,   11797.90437346,   42660.61267145,
#           73523.32096943,  104386.02926742,  135248.7375654 ,
#          166111.44586339,  196974.15416137,  227836.86245936,
#          258699.57075734,  289562.27905533,  320424.98735331,
#          351287.6956513 ,  382150.40394928,  413013.11224727,
#          443875.82054525,  474738.52884324,  505601.23714122,
#          536463.94543921]),
#  <BarContainer object of 30 artists>)

# %%
#상자도표
np.random.seed(42) #이걸 실행해보면 똑같음. 
#데이터가 바뀌고 차트가 바뀌면 이미 했던것들이 또 랜덤으로 돌아감...
#표본으로 뽑는 데이터를 고정하기 위해 (42)를 사용하는거임. opt랑 똑가틈.

sales = np.random.normal(50000, 10000, 100)
marketing = np.random.normal(55000, 12000, 100)
it = np.random.normal(60000, 15000, 100)

# %%
sales
# Out:
# array([54967.14153011, 48617.35698829, 56476.88538101, 65230.29856408,
#        47658.46625277, 47658.63043051, 65792.12815507, 57674.34729153,
#        45305.25614065, 55425.60043586, 45365.82307188, 45342.7024643 ,
#        52419.62271566, 30867.19755342, 32750.82167487, 44377.12470759,
#        39871.68879666, 53142.47332595, 40919.75924479, 35876.96298665,
#        64656.48768922, 47742.23699513, 50675.28204688, 35752.51813787,
#        44556.17275475, 51109.2258971 , 38490.06422578, 53756.98018346,
#        43993.61310081, 47083.06250207, 43982.93387771, 68522.78184509,
#        49865.02775262, 39422.89071044, 58225.44912103, 37791.56350029,
#        52088.63595005, 30403.2987612 , 36718.13951102, 51968.61235869,
#        57384.66579995, 51713.6828119 , 48843.51717612, 46988.96304411,
#        35214.78009633, 42801.55791605, 45393.6122904 , 60571.22226219,
#        53436.18289568, 32369.59844637, 53240.83969395, 46149.17719584,
#        43230.77999694, 56116.76288841, 60309.99522496, 59312.80119116,
#        41607.82476777, 46907.87624149, 53312.63431404, 59755.45127122,
#        45208.25762155, 48143.41023336, 38936.65025994, 38037.93375919,
#        58125.25822394, 63562.40028571, 49279.8987842 , 60035.32897892,
#        53616.36025048, 43548.80245395, 53613.95605508, 65380.36566466,
#        49641.7396089 , 65646.43655814, 23802.5489591 , 58219.02504375,
#        50870.47068238, 47009.92649534, 50917.60776536, 30124.31085399,
#        47803.28112162, 53571.12571512, 64778.94044742, 44817.29781726,
#        41915.06397107, 44982.42956415, 59154.02117702, 53287.5110966 ,
#        44702.39796233, 55132.67433113, 50970.77549348, 59686.44990533,
#        42979.46906123, 46723.37853402, 46078.91846868, 35364.85051868,
#        52961.20277065, 52610.5527218 , 50051.13456642, 47654.12866625])

# %%
sales #값이 위에랑 다름!! 이유는 random
# Out:
# array([54967.14153011, 48617.35698829, 56476.88538101, 65230.29856408,
#        47658.46625277, 47658.63043051, 65792.12815507, 57674.34729153,
#        45305.25614065, 55425.60043586, 45365.82307188, 45342.7024643 ,
#        52419.62271566, 30867.19755342, 32750.82167487, 44377.12470759,
#        39871.68879666, 53142.47332595, 40919.75924479, 35876.96298665,
#        64656.48768922, 47742.23699513, 50675.28204688, 35752.51813787,
#        44556.17275475, 51109.2258971 , 38490.06422578, 53756.98018346,
#        43993.61310081, 47083.06250207, 43982.93387771, 68522.78184509,
#        49865.02775262, 39422.89071044, 58225.44912103, 37791.56350029,
#        52088.63595005, 30403.2987612 , 36718.13951102, 51968.61235869,
#        57384.66579995, 51713.6828119 , 48843.51717612, 46988.96304411,
#        35214.78009633, 42801.55791605, 45393.6122904 , 60571.22226219,
#        53436.18289568, 32369.59844637, 53240.83969395, 46149.17719584,
#        43230.77999694, 56116.76288841, 60309.99522496, 59312.80119116,
#        41607.82476777, 46907.87624149, 53312.63431404, 59755.45127122,
#        45208.25762155, 48143.41023336, 38936.65025994, 38037.93375919,
#        58125.25822394, 63562.40028571, 49279.8987842 , 60035.32897892,
#        53616.36025048, 43548.80245395, 53613.95605508, 65380.36566466,
#        49641.7396089 , 65646.43655814, 23802.5489591 , 58219.02504375,
#        50870.47068238, 47009.92649534, 50917.60776536, 30124.31085399,
#        47803.28112162, 53571.12571512, 64778.94044742, 44817.29781726,
#        41915.06397107, 44982.42956415, 59154.02117702, 53287.5110966 ,
#        44702.39796233, 55132.67433113, 50970.77549348, 59686.44990533,
#        42979.46906123, 46723.37853402, 46078.91846868, 35364.85051868,
#        52961.20277065, 52610.5527218 , 50051.13456642, 47654.12866625])

# %%
data = [sales, marketing, it] #numpy arrary의 리스트
labels = ['Sales', 'Marketing', 'IT']

# %%
plt.figure(figsize= (12,5))
plt.boxplot(data, labels=labels)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1180\2810381029.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)
# {'whiskers': [<matplotlib.lines.Line2D at 0x24a19d02e30>,
#   <matplotlib.lines.Line2D at 0x24a19d03130>,
#   <matplotlib.lines.Line2D at 0x24a19e84280>,
#   <matplotlib.lines.Line2D at 0x24a19e84580>,
#   <matplotlib.lines.Line2D at 0x24a19e85780>,
#   <matplotlib.lines.Line2D at 0x24a19e85a80>],
#  'caps': [<matplotlib.lines.Line2D at 0x24a19d03310>,
#   <matplotlib.lines.Line2D at 0x24a19d03610>,
#   <matplotlib.lines.Line2D at 0x24a19e84880>,
#   <matplotlib.lines.Line2D at 0x24a19e84b80>,
#   <matplotlib.lines.Line2D at 0x24a19e85d80>,
#   <matplotlib.lines.Line2D at 0x24a19e86080>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24a19d02b30>,
#   <matplotlib.lines.Line2D at 0x24a19d03f40>,
#   <matplotlib.lines.Line2D at 0x24a19e85480>],
#  'medians': [<matplotlib.lines.Line2D at 0x24a19d03910>,
#   <matplotlib.lines.Line2D at 0x24a19e84e80>,
#   <matplotlib.lines.Line2D at 0x24a19e86380>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24a19d03c10>,
#   <matplotlib.lines.Line2D at 0x24a19e85180>,
#   <matplotlib.lines.Line2D at 0x24a19e86680>],
#  'means': []}

# %%
#산점도
# 데이터 준비 (광고비와 매출액의 관계)
np.random.seed(42)
ad_spend = np.random.uniform(10, 100, 100)  # 광고비 (만원)
sales = 2.5 * ad_spend + np.random.normal(0, 15, 100)  # 매출액 (만원)
sales
# Out:
# array([110.57723276, 234.42560869, 191.07504856, 129.88462523,
#         56.80911578,  65.45545565,  60.23722341, 212.11557953,
#        148.1234736 , 176.78997435,  43.36254298, 248.16098338,
#        204.35319112,  80.4753114 ,  67.36678086,  80.79568958,
#         82.92370826, 138.15526492, 116.3060069 ,  68.57383232,
#        167.10870547,  60.30194773,  90.80924777, 103.91260774,
#        106.38518532, 195.35491147,  64.78588324, 128.6685896 ,
#        155.87399232,  41.51210571, 189.9903802 ,  65.98659502,
#         43.49986428, 237.38255715, 213.48563921, 206.49169519,
#         94.44155121,  83.92485734, 176.06701649, 128.55752123,
#         51.93792629, 118.88463421,  49.87975947, 240.87608596,
#         95.09097507, 160.42670216, 116.17690678, 120.98753882,
#        156.81266926,  99.44908688, 228.29849637, 190.91041931,
#        237.88203233, 218.78401903, 136.26754377, 233.4501475 ,
#         28.97625726,  76.2000305 ,  21.38477649, 121.4483405 ,
#        100.7035908 ,  81.22260941, 223.66869782,  86.80653376,
#         91.6221637 , 166.71376002,  32.5957021 , 208.26382855,
#         45.67213674, 258.77690381, 180.20081243,  49.90417915,
#         34.07159984, 212.9335915 , 187.80029512, 194.22333595,
#        188.33545718,  45.1438521 , 110.05087602,  40.35526712,
#        247.18488849, 172.34957235,  81.58250313,  49.14893294,
#         80.35079733, 109.97251651, 206.54032381, 156.14019628,
#        239.07350902, 137.44007207,  64.23960774, 213.93197186,
#        192.4958142 , 139.98132699, 185.12489905, 123.86685491,
#        141.45836097, 126.31400875,  34.86966551,  61.68331981])

# %%
ad_spend
# Out:
# array([43.7086107 , 95.56428758, 75.87945476, 63.87926358, 24.04167764,
#        24.03950683, 15.2275251 , 87.95585312, 64.10035106, 73.726532  ,
#        11.85260449, 97.29188669, 84.91983767, 29.11051996, 26.36424705,
#        26.50640589, 37.38180187, 57.22807885, 48.87505168, 36.21062262,
#        65.06676053, 22.55444746, 36.29301837, 42.9725659 , 51.04629858,
#        80.66583653, 27.97064039, 56.28109946, 63.3173112 , 14.18053714,
#        64.67903667, 25.34717113, 15.85464337, 95.39969835, 96.90688298,
#        82.75576133, 37.41523923, 18.79049026, 71.58097239, 49.61372444,
#        20.98344114, 54.56592191, 13.0949669 , 91.83883619, 33.29019834,
#        69.62700559, 38.05399685, 56.80612191, 59.20392514, 26.636901  ,
#        97.2626165 , 79.7619541 , 94.55490474, 90.53446154, 63.81099809,
#        92.96868115, 17.96432518, 27.63845762, 14.070456  , 39.27972977,
#        44.98095607, 34.42141286, 84.58637582, 42.1077994 , 35.28410587,
#        58.84264748, 22.68318025, 82.19772827, 16.70955793, 98.81982429,
#        79.50202924, 27.88441134, 10.49699054, 83.39152856, 73.61716095,
#        75.61064512, 79.4143312 , 16.66401866, 42.26191557, 20.42821536,
#        87.67930833, 66.09683141, 39.78082224, 15.72025153, 37.98840895,
#        39.26649898, 75.66455605, 67.38017242, 89.84914683, 52.49934326,
#        20.76348213, 74.19203085, 78.47065438, 60.51494778, 79.3870462 ,
#        54.44160367, 57.04595464, 48.47869165, 12.28772141, 19.71022843])

# %%
plt.scatter(ad_spend, sales)
# 추세선 추가
z = np.polyfit(ad_spend, sales, 1)
p = np.poly1d(z)
plt.plot(ad_spend, p(ad_spend), "r--", alpha=0.8, label='Trend Line')
plt.legend()

# %% [markdown]
# # 상관분석 실습

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"

# 이 데이터셋의 표준 컬럼명 (직접 지정 필요)
column_names = [
    'CRIM',    # 1인당 범죄율
    'ZN',      # 25,000평방피트 초과 주거 지역 비율
    'INDUS',   # 비소매 상업 지역 비율
    'CHAS',    # 찰스강 더미 변수 (1: 강 경계, 0: 아님)
    'NOX',     # 일산화질소 농도
    'RM',      # 주택당 평균 방 개수
    'AGE',     # 1940년 이전에 건축된 소유 주택 비율
    'DIS',     # 5개 보스턴 고용 센터까지의 가중 거리
    'RAD',     # 방사형 고속도로 접근성 지수
    'TAX',     # 10,000달러당 재산세율
    'PTRATIO', # 학생-교사 비율
    'B',       # 흑인 인구 비율 (현재는 윤리적 이슈로 사용 지양 권고되기도 함)
    'LSTAT',   # 하위 계층 비율 (%)
    'MEDV'     # 본인 소유 주택 가격(중앙값) - 타겟 변수
]

# %%
import pandas as pd

# %%
df = pd.read_csv(url, sep='\s+', header=None, names=column_names) #csv 값들이 comma로 나눠져있는거

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
room_cnt = df['RM']
house_price = df['MEDV']

# %%
#추세선 추가 
z = np.polyfit(room_cnt, house_price, 1)
p = np.poly1d(z)
plt.plot(room_cnt, p(room_cnt), "r--", alpha = 0.8, label='Trend Line') #r--점선으로 표시해라는 말
plt.scatter(room_cnt, house_price)

# %%
#산점도 그려보기
plt.scatter(df['RM'], df['MEDV'])

# %%
plt.scatter(df['AGE'], df['MEDV'])

# %%
plt.scatter(df['CRIM'], df['MEDV'])
